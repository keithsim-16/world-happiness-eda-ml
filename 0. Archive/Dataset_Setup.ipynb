# %% [markdown]
# # 2015 UNData

# %%
# Basic Libraries
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt # we only need pyplot
sb.set() # set the default Seaborn style for graphics

# %% [markdown]
# ## Individuals using the Internet (per 100 inhabitants)

# %%
Internet_Usage = pd.read_csv('Internet_Usage.csv', encoding = "ISO-8859-1")
new_header = Internet_Usage.iloc[0] #grab the first row for the header
Internet_Usage = Internet_Usage[1:] #take the data less the header row
Internet_Usage.columns = new_header #set the header row as the df header
Internet_Usage.head()
# Out:
# 0 Region/Country/Area                            NaN  Year  \
# 1                   1  Total, all countries or areas  2000
# 2                   1  Total, all countries or areas  2005
# 3                   1  Total, all countries or areas  2010
# 4                   1  Total, all countries or areas  2015
# 5                   1  Total, all countries or areas  2017
#
# 0                                        Series Value Footnotes  \
# 1  Percentage of individuals using the internet   6.5       NaN
# 2  Percentage of individuals using the internet  16.8       NaN
# 3  Percentage of individuals using the internet  29.3       NaN
# 4  Percentage of individuals using the internet  41.1       NaN
# 5  Percentage of individuals using the internet  46.3       NaN
#
# 0                                             Source
# 1  International Telecommunication Union (ITU), G...
# 2  International Telecommunication Union (ITU), G...
# 3  International Telecommunication Union (ITU), G...
# 4  International Telecommunication Union (ITU), G...
# 5  International Telecommunication Union (ITU), G...

# %%
Internet_Usage.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1357 entries, 1 to 1357
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Region/Country/Area  1357 non-null   object
#  1   nan                  1357 non-null   object
#  2   Year                 1357 non-null   object
#  3   Series               1357 non-null   object
#  4   Value                1357 non-null   object
#  5   Footnotes            599 non-null    object
#  6   Source               1357 non-null   object
# dtypes: object(7)
# memory usage: 74.3+ KB

# %%
cols = list(Internet_Usage.columns)
cols[1] = 'country'
Internet_Usage.columns = cols

# %%
continents = ['Total, all countries or areas', 'Northern Africa', 'Sub-Saharan Africa', 'Eastern Africa', 
              'Middle Africa', 'Southern Africa', 'Western Africa', 'Northern America', 
              'Latin America & the Caribbean', 'Caribbean', 'Latin America', 'Asia', 'Central Asia', 
              'Eastern Asia', 'South-central Asia', 'South-eastern Asia', 'Southern Asia', 'Western Asia', 
              'Europe', 'Oceania', 'Australia and New Zealand', 'Africa', 'Americas', 'Central America', 
              'South America', 'Caucasus', 'Melanesia', 'Micronesia', 'Polynesia']
for i in continents:
    Internet_Usage= Internet_Usage[Internet_Usage['country'].str.contains(i)==False]

# %%
Internet_Usage= Internet_Usage[Internet_Usage['Year'].str.contains('2015')!=False]

# %%
Internet_Usage = Internet_Usage.rename(columns={'Value': 'Individuals using the Internet (per 100 inhabitants)'})
Internet_Usage = pd.DataFrame(Internet_Usage[['country', 'Individuals using the Internet (per 100 inhabitants)']])
Internet_Usage
# Out:
#                          country  \
# 150                  Afghanistan
# 155                      Albania
# 161                      Algeria
# 167                      Andorra
# 172                       Angola
# ...                          ...
# 1330  Venezuela (Boliv. Rep. of)
# 1335                    Viet Nam
# 1345                       Yemen
# 1350                      Zambia
# 1356                    Zimbabwe
#
#      Individuals using the Internet (per 100 inhabitants)
# 150                                                 8.3
# 155                                                63.3
# 161                                                38.2
# 167                                                96.9
# 172                                                12.4
# ...                                                 ...
# 1330                                                 64
# 1335                                                 45
# 1345                                               24.1
# 1350                                                 21
# 1356                                               22.7
#
# [202 rows x 2 columns]

# %% [markdown]
# ## Employment

# %%
Employment = pd.read_csv('Employment.csv', encoding = "ISO-8859-1")
new_header = Employment.iloc[0] #grab the first row for the header
Employment = Employment[1:] #take the data less the header row
Employment.columns = new_header #set the header row as the df header
Employment.head()
# Out:
# 0 Region/Country/Area                            NaN  Year  \
# 1                   1  Total, all countries or areas  2005
# 2                   1  Total, all countries or areas  2005
# 3                   1  Total, all countries or areas  2005
# 4                   1  Total, all countries or areas  2005
# 5                   1  Total, all countries or areas  2005
#
# 0                                             Series Value  Footnotes  \
# 1  Employment by industry: Agriculture (%) Male a...  37.0  Estimate.
# 2  Employment by industry: Industry (%) Male and ...  21.2  Estimate.
# 3  Employment by industry: Services (%) Male and ...  41.8  Estimate.
# 4       Employment by industry: Agriculture (%) Male  37.3  Estimate.
# 5          Employment by industry: Industry (%) Male  24.2  Estimate.
#
# 0                                             Source
# 1  International Labour Organization (ILO), Genev...
# 2  International Labour Organization (ILO), Genev...
# 3  International Labour Organization (ILO), Genev...
# 4  International Labour Organization (ILO), Genev...
# 5  International Labour Organization (ILO), Genev...

# %%
cols = list(Employment.columns)
cols[1] = 'country'
Employment.columns = cols

# %%
for i in continents:
    Employment = Employment[Employment['country'].str.contains(i)==False]

# %%
Employment = Employment[Employment['Year'].str.contains('2015')!=False]
Employment_Services = Employment.loc[Employment['Series'] == 'Employment by industry: Services (%) Male and Female']
Employment_Agriculture = Employment.loc[Employment['Series'] == 'Employment by industry: Agriculture (%) Male and Female']

# %%
Employment_Services
# Out:
#      Region/Country/Area         country  Year  \
# 849                    4     Afghanistan  2015
# 885                    8         Albania  2015
# 921                   12         Algeria  2015
# 963                   24          Angola  2015
# 1026                  32       Argentina  2015
# ...                  ...             ...   ...
# 7770                 704        Viet Nam  2015
# 7806                 732  Western Sahara  2015
# 7842                 887           Yemen  2015
# 7878                 894          Zambia  2015
# 7914                 716        Zimbabwe  2015
#
#                                                  Series Value  Footnotes  \
# 849   Employment by industry: Services (%) Male and ...  35.8  Estimate.
# 885   Employment by industry: Services (%) Male and ...  40.0        NaN
# 921   Employment by industry: Services (%) Male and ...  58.7  Estimate.
# 963   Employment by industry: Services (%) Male and ...  40.8  Estimate.
# 1026  Employment by industry: Services (%) Male and ...  76.1  Estimate.
# ...                                                 ...   ...        ...
# 7770  Employment by industry: Services (%) Male and ...  33.2        NaN
# 7806  Employment by industry: Services (%) Male and ...  53.0  Estimate.
# 7842  Employment by industry: Services (%) Male and ...  58.0  Estimate.
# 7878  Employment by industry: Services (%) Male and ...  37.7  Estimate.
# 7914  Employment by industry: Services (%) Male and ...  25.7  Estimate.
#
#                                                  Source
# 849   International Labour Organization (ILO), Genev...
# 885   International Labour Organization (ILO), Genev...
# 921   International Labour Organization (ILO), Genev...
# 963   International Labour Organization (ILO), Genev...
# 1026  International Labour Organization (ILO), Genev...
# ...                                                 ...
# 7770  International Labour Organization (ILO), Genev...
# 7806  International Labour Organization (ILO), Genev...
# 7842  International Labour Organization (ILO), Genev...
# 7878  International Labour Organization (ILO), Genev...
# 7914  International Labour Organization (ILO), Genev...
#
# [185 rows x 7 columns]

# %%
Employment_Agriculture
# Out:
#      Region/Country/Area         country  Year  \
# 847                    4     Afghanistan  2015
# 883                    8         Albania  2015
# 919                   12         Algeria  2015
# 961                   24          Angola  2015
# 1024                  32       Argentina  2015
# ...                  ...             ...   ...
# 7768                 704        Viet Nam  2015
# 7804                 732  Western Sahara  2015
# 7840                 887           Yemen  2015
# 7876                 894          Zambia  2015
# 7912                 716        Zimbabwe  2015
#
#                                                  Series Value  Footnotes  \
# 847   Employment by industry: Agriculture (%) Male a...  47.1  Estimate.
# 883   Employment by industry: Agriculture (%) Male a...  41.4        NaN
# 919   Employment by industry: Agriculture (%) Male a...  10.3  Estimate.
# 961   Employment by industry: Agriculture (%) Male a...  50.6  Estimate.
# 1024  Employment by industry: Agriculture (%) Male a...   0.3  Estimate.
# ...                                                 ...   ...        ...
# 7768  Employment by industry: Agriculture (%) Male a...  44.0        NaN
# 7804  Employment by industry: Agriculture (%) Male a...  21.9  Estimate.
# 7840  Employment by industry: Agriculture (%) Male a...  29.2  Estimate.
# 7876  Employment by industry: Agriculture (%) Male a...  51.7  Estimate.
# 7912  Employment by industry: Agriculture (%) Male a...  67.2  Estimate.
#
#                                                  Source
# 847   International Labour Organization (ILO), Genev...
# 883   International Labour Organization (ILO), Genev...
# 919   International Labour Organization (ILO), Genev...
# 961   International Labour Organization (ILO), Genev...
# 1024  International Labour Organization (ILO), Genev...
# ...                                                 ...
# 7768  International Labour Organization (ILO), Genev...
# 7804  International Labour Organization (ILO), Genev...
# 7840  International Labour Organization (ILO), Genev...
# 7876  International Labour Organization (ILO), Genev...
# 7912  International Labour Organization (ILO), Genev...
#
# [185 rows x 7 columns]

# %% [markdown]
# ### Employment: Services (% of employed)

# %%
Employment_Services = pd.DataFrame(Employment_Services[['country', 'Value']])
Employment_Services = Employment_Services.rename(columns={'Value': 'Employment: Services (% of employed)'})
Employment_Services
# Out:
#              country Employment: Services (% of employed)
# 849      Afghanistan                                 35.8
# 885          Albania                                 40.0
# 921          Algeria                                 58.7
# 963           Angola                                 40.8
# 1026       Argentina                                 76.1
# ...              ...                                  ...
# 7770        Viet Nam                                 33.2
# 7806  Western Sahara                                 53.0
# 7842           Yemen                                 58.0
# 7878          Zambia                                 37.7
# 7914        Zimbabwe                                 25.7
#
# [185 rows x 2 columns]

# %% [markdown]
# ### Employment: Agriculture (% of employed)

# %%
Employment_Agriculture = pd.DataFrame(Employment_Agriculture[['country', 'Value']])
Employment_Agriculture = Employment_Agriculture.rename(columns={'Value': 'Employment: Agriculture (% of employed)'})
Employment_Agriculture
# Out:
#              country Employment: Agriculture (% of employed)
# 847      Afghanistan                                    47.1
# 883          Albania                                    41.4
# 919          Algeria                                    10.3
# 961           Angola                                    50.6
# 1024       Argentina                                     0.3
# ...              ...                                     ...
# 7768        Viet Nam                                    44.0
# 7804  Western Sahara                                    21.9
# 7840           Yemen                                    29.2
# 7876          Zambia                                    51.7
# 7912        Zimbabwe                                    67.2
#
# [185 rows x 2 columns]

# %% [markdown]
# ## GDP per capita (current US$)

# %%
GDP = pd.read_csv('GDP.csv', encoding = "ISO-8859-1")
new_header = GDP.iloc[0] #grab the first row for the header
GDP = GDP[1:] #take the data less the header row
GDP.columns = new_header #set the header row as the df header
GDP.head()
# Out:
# 0 Region/Country/Area                            NaN  Year  \
# 1                   1  Total, all countries or areas  1995
# 2                   1  Total, all countries or areas  2005
# 3                   1  Total, all countries or areas  2010
# 4                   1  Total, all countries or areas  2015
# 5                   1  Total, all countries or areas  2017
#
# 0                                          Series       Value Footnotes  \
# 1  GDP in current prices (millions of US dollars)  31,140,783       NaN
# 2  GDP in current prices (millions of US dollars)  47,623,151       NaN
# 3  GDP in current prices (millions of US dollars)  66,272,559       NaN
# 4  GDP in current prices (millions of US dollars)  74,985,744       NaN
# 5  GDP in current prices (millions of US dollars)  81,056,929       NaN
#
# 0                                             Source
# 1  United Nations Statistics Division, New York, ...
# 2  United Nations Statistics Division, New York, ...
# 3  United Nations Statistics Division, New York, ...
# 4  United Nations Statistics Division, New York, ...
# 5  United Nations Statistics Division, New York, ...

# %%
# Remove duplicate column name that caused columns names to shift left
cols = list(GDP.columns)
cols[1] = 'country'
GDP.columns = cols

# %%
for i in continents:
    GDP = GDP[GDP['country'].str.contains(i)==False]

# %%
GDP
# Out:
#      Region/Country/Area      country  Year  \
# 841                    4  Afghanistan  1995
# 842                    4  Afghanistan  2005
# 843                    4  Afghanistan  2010
# 844                    4  Afghanistan  2015
# 845                    4  Afghanistan  2017
# ...                  ...          ...   ...
# 6769                 716     Zimbabwe  2010
# 6770                 716     Zimbabwe  2015
# 6771                 716     Zimbabwe  2017
# 6772                 716     Zimbabwe  2018
# 6773                 716     Zimbabwe  2019
#
#                                               Series   Value Footnotes  \
# 841   GDP in current prices (millions of US dollars)   2,757       NaN
# 842   GDP in current prices (millions of US dollars)   6,221       NaN
# 843   GDP in current prices (millions of US dollars)  14,699       NaN
# 844   GDP in current prices (millions of US dollars)  18,713       NaN
# 845   GDP in current prices (millions of US dollars)  18,623       NaN
# ...                                              ...     ...       ...
# 6769              GDP real rates of growth (percent)    19.7       NaN
# 6770              GDP real rates of growth (percent)     1.8       NaN
# 6771              GDP real rates of growth (percent)     4.7       NaN
# 6772              GDP real rates of growth (percent)     4.8       NaN
# 6773              GDP real rates of growth (percent)    -8.1       NaN
#
#                                                  Source
# 841   United Nations Statistics Division, New York, ...
# 842   United Nations Statistics Division, New York, ...
# 843   United Nations Statistics Division, New York, ...
# 844   United Nations Statistics Division, New York, ...
# 845   United Nations Statistics Division, New York, ...
# ...                                                 ...
# 6769  United Nations Statistics Division, New York, ...
# 6770  United Nations Statistics Division, New York, ...
# 6771  United Nations Statistics Division, New York, ...
# 6772  United Nations Statistics Division, New York, ...
# 6773  United Nations Statistics Division, New York, ...
#
# [5821 rows x 7 columns]

# %%
GDP = GDP[GDP['Year'].str.contains('2015')!=False]
GDP = GDP.loc[GDP['Series'] == 'GDP per capita (US dollars)']

# %%
GDP = GDP.rename(columns={'Value': 'GDP per capita (current US$)'})
GDP = pd.DataFrame(GDP[['country', 'GDP per capita (current US$)']])

# %%
GDP['GDP per capita (current US$)']=GDP['GDP per capita (current US$)'].str.replace(',','')
GDP
# Out:
#           country GDP per capita (current US$)
# 851   Afghanistan                          544
# 879       Albania                         3939
# 907       Algeria                         4178
# 935       Andorra                        35748
# 963        Angola                         4167
# ...           ...                          ...
# 6644     Viet Nam                         2085
# 6672        Yemen                         1006
# 6700       Zambia                         1314
# 6728     Zanzibar                          821
# 6756     Zimbabwe                         1445
#
# [208 rows x 2 columns]

# %% [markdown]
# ## Infant Mortality & Fertility

# %%
Infant = pd.read_csv('Population_Fertility.csv', encoding = "ISO-8859-1")
new_header = Infant.iloc[0] #grab the first row for the header
Infant = Infant[1:] #take the data less the header row
Infant.columns = new_header #set the header row as the df header
Infant.head()
# Out:
# 0 Region/Country/Area                            NaN  Year  \
# 1                   1  Total, all countries or areas  2010
# 2                   1  Total, all countries or areas  2010
# 3                   1  Total, all countries or areas  2010
# 4                   1  Total, all countries or areas  2010
# 5                   1  Total, all countries or areas  2010
#
# 0                                             Series Value  \
# 1       Population annual rate of increase (percent)   1.2
# 2          Total fertility rate (children per women)   2.6
# 3  Infant mortality for both sexes (per 1,000 liv...  41.0
# 4  Maternal mortality ratio (deaths per 100,000 p...   248
# 5    Life expectancy at birth for both sexes (years)  68.9
#
# 0                                          Footnotes  \
# 1  Data refers to a 5-year period preceding the r...
# 2  Data refers to a 5-year period preceding the r...
# 3  Data refers to a 5-year period preceding the r...
# 4                                                NaN
# 5  Data refers to a 5-year period preceding the r...
#
# 0                                             Source
# 1  United Nations Population Division, New York, ...
# 2  United Nations Population Division, New York, ...
# 3  United Nations Statistics Division, New York, ...
# 4  World Health Organization (WHO), the United Na...
# 5  United Nations Population Division, New York, ...

# %%
# Remove duplicate column name that caused columns names to shift left
cols = list(Infant.columns)
cols[1] = 'country'
Infant.columns = cols

# %%
for i in continents:
    Infant = Infant[Infant['country'].str.contains(i)==False]

# %%
Infant = Infant[Infant['Year'].str.contains('2015')!=False]
Infant_Mortality = Infant.loc[Infant['Series'] == 'Infant mortality for both sexes (per 1,000 live births)']
Infant_Fertility = Infant.loc[Infant['Series'] == 'Total fertility rate (children per women)']

# %% [markdown]
# ### Infant mortality rate (per 1000 live births

# %%
Infant_Mortality = pd.DataFrame(Infant_Mortality[['country', 'Value']])
Infant_Mortality = Infant_Mortality.rename(columns={'Value': 'Infant mortality rate (per 1000 live births'})
Infant_Mortality
# Out:
#                   country Infant mortality rate (per 1000 live births
# 634           Afghanistan                                        60.1
# 655               Albania                                         9.2
# 676               Algeria                                        24.9
# 703                Angola                                        78.2
# 727   Antigua and Barbuda                                         6.8
# ...                   ...                                         ...
# 4804             Viet Nam                                        17.9
# 4827       Western Sahara                                        34.1
# 4846                Yemen                                        43.3
# 4867               Zambia                                        53.3
# 4888             Zimbabwe                                        51.2
#
# [197 rows x 2 columns]

# %% [markdown]
# ### Fertility rate, total (live births per woman)

# %%
Infant_Fertility = pd.DataFrame(Infant_Fertility[['country', 'Value']])
Infant_Fertility = Infant_Fertility.rename(columns={'Value': 'Fertility rate, total (live births per woman)'})
Infant_Fertility
# Out:
#                   country Fertility rate, total (live births per woman)
# 633           Afghanistan                                           5.4
# 654               Albania                                           1.7
# 675               Algeria                                           3.0
# 702                Angola                                           6.0
# 726   Antigua and Barbuda                                           2.0
# ...                   ...                                           ...
# 4803             Viet Nam                                           2.0
# 4826       Western Sahara                                           2.6
# 4845                Yemen                                           4.4
# 4866               Zambia                                           5.2
# 4887             Zimbabwe                                           4.1
#
# [197 rows x 2 columns]

# %% [markdown]
# ## Urban population (% of total population)

# %%
Upop = pd.read_csv('Population_Growth.csv', encoding = "ISO-8859-1")
new_header = Upop.iloc[0] #grab the first row for the header
Upop = Upop[1:] #take the data less the header row
Upop.columns = new_header #set the header row as the df header
Upop.head()
# Out:
# 0 Region/Country/Area                            NaN  Year  \
# 1                   1  Total, all countries or areas  2005
# 2                   1  Total, all countries or areas  2005
# 3                   1  Total, all countries or areas  2005
# 4                   1  Total, all countries or areas  2010
# 5                   1  Total, all countries or areas  2010
#
# 0                                            Series Capital City  \
# 1                        Urban population (percent)          NaN
# 2  Urban population (percent growth rate per annum)          NaN
# 3  Rural population (percent growth rate per annum)          NaN
# 4                        Urban population (percent)          NaN
# 5  Urban population (percent growth rate per annum)          NaN
#
# 0 Capital City footnote Value  \
# 1                   NaN  49.2
# 2                   NaN   2.3
# 3                   NaN   0.3
# 4                   NaN  51.7
# 5                   NaN   2.2
#
# 0                                          Footnotes  \
# 1                                                NaN
# 2  Data refers to a 5-year period preceding the r...
# 3  Data refers to a 5-year period preceding the r...
# 4                                                NaN
# 5  Data refers to a 5-year period preceding the r...
#
# 0                                             Source
# 1  United Nations Population Division, New York, ...
# 2  United Nations Population Division, New York, ...
# 3  United Nations Population Division, New York, ...
# 4  United Nations Population Division, New York, ...
# 5  United Nations Population Division, New York, ...

# %%
# Remove duplicate column name that caused columns names to shift left
cols = list(Upop.columns)
cols[1] = 'country'
Upop.columns = cols

# %%
for i in continents:
    Upop = Upop[Upop['country'].str.contains(i)==False]

# %%
Upop = Upop[Upop['Year'].str.contains('2015')!=False]
Upop = Upop.loc[Upop['Series'] == 'Urban population (percent)']

# %%
Upop = pd.DataFrame(Upop[['country', 'Value']])
Upop = Upop.rename(columns={'Value': 'Urban population (% of total population)'})
Upop
# Out:
#                         country Urban population (% of total population)
# 303                 Afghanistan                                     24.8
# 323                     Albania                                     57.4
# 343                     Algeria                                     70.8
# 357              American Samoa                                     87.2
# 368                     Andorra                                     88.3
# ...                         ...                                      ...
# 4090  Wallis and Futuna Islands                                        0
# 4101             Western Sahara                                     86.5
# 4118                      Yemen                                     34.8
# 4138                     Zambia                                     41.9
# 4158                   Zimbabwe                                     32.4
#
# [228 rows x 2 columns]

# %% [markdown]
# ## Economy: Agriculture (% of GVA)

# %%
GVA = pd.read_csv('Gross_Value.csv', encoding = "ISO-8859-1")
new_header = GVA.iloc[0] #grab the first row for the header
GVA = GVA[1:] #take the data less the header row
GVA.columns = new_header #set the header row as the df header
GVA.head()
# Out:
# 0 Region/Country/Area          NaN  Year  \
# 1                   4  Afghanistan  2005
# 2                   4  Afghanistan  2010
# 3                   4  Afghanistan  2015
# 4                   4  Afghanistan  2018
# 5                   4  Afghanistan  2019
#
# 0                                             Series Value  \
# 1  Agriculture, hunting, forestry and fishing (% ...  37.3
# 2  Agriculture, hunting, forestry and fishing (% ...  33.2
# 3  Agriculture, hunting, forestry and fishing (% ...  27.3
# 4  Agriculture, hunting, forestry and fishing (% ...  23.7
# 5  Agriculture, hunting, forestry and fishing (% ...  26.9
#
# 0                                         Footnotes  \
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4  Excludes irrigation canals and landscaping care.
# 5  Excludes irrigation canals and landscaping care.
#
# 0                                             Source
# 1  United Nations Statistics Division, New York, ...
# 2  United Nations Statistics Division, New York, ...
# 3  United Nations Statistics Division, New York, ...
# 4  United Nations Statistics Division, New York, ...
# 5  United Nations Statistics Division, New York, ...

# %%
# Remove duplicate column name that caused columns names to shift left
cols = list(GVA.columns)
cols[1] = 'country'
GVA.columns = cols

# %%
for i in continents:
    GVA = GVA[GVA['country'].str.contains(i)==False]

# %%
GVA = GVA[GVA['Year'].str.contains('2015')!=False]
GVA = GVA.loc[GVA['Series'] == 'Agriculture, hunting, forestry and fishing (% of gross value added)']

# %%
GVA = pd.DataFrame(GVA[['country', 'Value']])
GVA = GVA.rename(columns={'Value': 'Economy: Agriculture (% of GVA)'})
GVA
# Out:
#           country Economy: Agriculture (% of GVA)
# 3     Afghanistan                            27.3
# 20        Albania                            22.5
# 37        Algeria                            12.1
# 54        Andorra                             0.6
# 71         Angola                             9.1
# ...           ...                             ...
# 3501     Viet Nam                            18.9
# 3518        Yemen                            18.2
# 3535       Zambia                             5.3
# 3552     Zanzibar                            24.2
# 3569     Zimbabwe                             9.3
#
# [205 rows x 2 columns]

# %% [markdown]
# ## Education

# %%
Education = pd.read_csv('Education.csv', encoding = "ISO-8859-1")
new_header = Education.iloc[0] #grab the first row for the header
Education = Education[1:] #take the data less the header row
Education.columns = new_header #set the header row as the df header
Education.head()
# Out:
# 0 Region/Country/Area                            NaN  Year  \
# 1                   1  Total, all countries or areas  2005
# 2                   1  Total, all countries or areas  2005
# 3                   1  Total, all countries or areas  2005
# 4                   1  Total, all countries or areas  2005
# 5                   1  Total, all countries or areas  2005
#
# 0                                             Series    Value Footnotes  \
# 1  Students enrolled in primary education (thousa...  679,013       NaN
# 2            Gross enrollment ratio - Primary (male)    104.5       NaN
# 3          Gross enrollment ratio - Primary (female)     99.7       NaN
# 4  Students enrolled in secondary education (thou...  509,274       NaN
# 5          Gross enrollment ratio - Secondary (male)     65.8       NaN
#
# 0                                             Source
# 1  United Nations Educational, Scientific and Cul...
# 2  United Nations Educational, Scientific and Cul...
# 3  United Nations Educational, Scientific and Cul...
# 4  United Nations Educational, Scientific and Cul...
# 5  United Nations Educational, Scientific and Cul...

# %%
# Remove duplicate column name that caused columns names to shift left
cols = list(Education.columns)
cols[1] = 'country'
Education.columns = cols

# %%
for i in continents:
    Education= Education[Education['country'].str.contains(i)==False]

Education=Education[Education['Year'].str.contains('2015')!=False]
Education.head()
# Out:
#     Region/Country/Area      country  Year  \
# 454                   4  Afghanistan  2015
# 455                   4  Afghanistan  2015
# 456                   4  Afghanistan  2015
# 457                   4  Afghanistan  2015
# 458                   4  Afghanistan  2015
#
#                                                 Series  Value Footnotes  \
# 454  Students enrolled in primary education (thousa...  6,199       NaN
# 455            Gross enrollment ratio - Primary (male)  122.7       NaN
# 456          Gross enrollment ratio - Primary (female)   83.5       NaN
# 457  Students enrolled in secondary education (thou...  2,651       NaN
# 458          Gross enrollment ratio - Secondary (male)   65.9       NaN
#
#                                                 Source
# 454  United Nations Educational, Scientific and Cul...
# 455  United Nations Educational, Scientific and Cul...
# 456  United Nations Educational, Scientific and Cul...
# 457  United Nations Educational, Scientific and Cul...
# 458  United Nations Educational, Scientific and Cul...

# %% [markdown]
# ### Education: Secondary gross enrol. ratio (female per 100 pop.)

# %%
Secondary_female = Education[Education.Series == "Gross enrollment ratio - Secondary (female)" ]
Secondary_female = Secondary_female.rename(columns={'Value': 'Education: Secondary gross enrol. ratio (female per 100 pop.)'})
Secondary_female = pd.DataFrame(Secondary_female[['country', 'Education: Secondary gross enrol. ratio (female per 100 pop.)']])
Secondary_female.head()
# Out:
#                  country  \
# 459          Afghanistan
# 495              Albania
# 630  Antigua and Barbuda
# 666            Argentina
# 698              Armenia
#
#     Education: Secondary gross enrol. ratio (female per 100 pop.)
# 459                                               36.8
# 495                                               95.1
# 630                                              109.3
# 666                                              110.2
# 698                                               88.3

# %% [markdown]
# ### Education: Secondary gross enrol. ratio (male per 100 pop.)

# %%
Secondary_male = Education[Education.Series == "Gross enrollment ratio - Secondary (male)" ]
Secondary_male = Secondary_male.rename(columns={'Value': 'Education: Secondary gross enrol. ratio (male per 100 pop.)'})
Secondary_male = pd.DataFrame(Secondary_male[['country', 'Education: Secondary gross enrol. ratio (male per 100 pop.)']])
Secondary_male.head()
# Out:
#                  country  \
# 458          Afghanistan
# 494              Albania
# 629  Antigua and Barbuda
# 665            Argentina
# 697              Armenia
#
#     Education: Secondary gross enrol. ratio (male per 100 pop.)
# 458                                               65.9
# 494                                               99.5
# 629                                              107.1
# 665                                              103.8
# 697                                               84.0

# %% [markdown]
# ### Education: Tertiary gross enrol. ratio (female per 100 pop.)

# %%
Tertiary_female = Education[Education.Series == "Gross enrollment ratio - Upper secondary level (female)" ]
Tertiary_female = Tertiary_female.rename(columns={'Value': 'Education: Tertiary gross enrol. ratio (female per 100 pop.)'})
Tertiary_female = pd.DataFrame(Tertiary_female[['country', 'Education: Tertiary gross enrol. ratio (female per 100 pop.)']])
Tertiary_female.head()
# Out:
#                  country  \
# 462          Afghanistan
# 498              Albania
# 633  Antigua and Barbuda
# 669            Argentina
# 701              Armenia
#
#     Education: Tertiary gross enrol. ratio (female per 100 pop.)
# 462                                               27.1
# 498                                               89.6
# 633                                               90.7
# 669                                               91.1
# 701                                               95.0

# %% [markdown]
# ### Education: Tertiary gross enrol. ratio (male per 100 pop.)

# %%
Tertiary_male = Education[Education.Series == "Gross enrollment ratio - Upper secondary level (male)" ]
Tertiary_male = Tertiary_male.rename(columns={'Value': 'Education: Tertiary gross enrol. ratio (male per 100 pop.)'})
Tertiary_male = pd.DataFrame(Tertiary_male[['country', 'Education: Tertiary gross enrol. ratio (male per 100 pop.)']])
Tertiary_male.head()
# Out:
#                  country  \
# 461          Afghanistan
# 497              Albania
# 632  Antigua and Barbuda
# 668            Argentina
# 700              Armenia
#
#     Education: Tertiary gross enrol. ratio (male per 100 pop.)
# 461                                               52.6
# 497                                               99.6
# 632                                               79.0
# 668                                               79.4
# 700                                               85.3

# %% [markdown]
# ## Life Expectancy

# %%
Life_Expectancy = pd.read_csv('population_fertility.csv', encoding = "ISO-8859-1")
new_header = Life_Expectancy.iloc[0] #grab the first row for the header
Life_Expectancy = Life_Expectancy[1:] #take the data less the header row
Life_Expectancy.columns = new_header #set the header row as the df header
Life_Expectancy.head()
# Out:
# 0 Region/Country/Area                            NaN  Year  \
# 1                   1  Total, all countries or areas  2010
# 2                   1  Total, all countries or areas  2010
# 3                   1  Total, all countries or areas  2010
# 4                   1  Total, all countries or areas  2010
# 5                   1  Total, all countries or areas  2010
#
# 0                                             Series Value  \
# 1       Population annual rate of increase (percent)   1.2
# 2          Total fertility rate (children per women)   2.6
# 3  Infant mortality for both sexes (per 1,000 liv...  41.0
# 4  Maternal mortality ratio (deaths per 100,000 p...   248
# 5    Life expectancy at birth for both sexes (years)  68.9
#
# 0                                          Footnotes  \
# 1  Data refers to a 5-year period preceding the r...
# 2  Data refers to a 5-year period preceding the r...
# 3  Data refers to a 5-year period preceding the r...
# 4                                                NaN
# 5  Data refers to a 5-year period preceding the r...
#
# 0                                             Source
# 1  United Nations Population Division, New York, ...
# 2  United Nations Population Division, New York, ...
# 3  United Nations Statistics Division, New York, ...
# 4  World Health Organization (WHO), the United Na...
# 5  United Nations Population Division, New York, ...

# %%
# Remove duplicate column name that caused columns names to shift left
cols = list(Life_Expectancy.columns)
cols[1] = 'country'
Life_Expectancy.columns = cols

# %%
for i in continents:
    Life_Expectancy= Life_Expectancy[Life_Expectancy['country'].str.contains(i)==False]
    
Life_Expectancy=Life_Expectancy[Life_Expectancy['Year'].str.contains('2015')!=False]
Life_Expectancy.head()
# Out:
#     Region/Country/Area      country  Year  \
# 632                   4  Afghanistan  2015
# 633                   4  Afghanistan  2015
# 634                   4  Afghanistan  2015
# 635                   4  Afghanistan  2015
# 636                   4  Afghanistan  2015
#
#                                                 Series Value  \
# 632       Population annual rate of increase (percent)   3.3
# 633          Total fertility rate (children per women)   5.4
# 634  Infant mortality for both sexes (per 1,000 liv...  60.1
# 635  Maternal mortality ratio (deaths per 100,000 p...   701
# 636    Life expectancy at birth for both sexes (years)  62.3
#
#                                              Footnotes  \
# 632  Data refers to a 5-year period preceding the r...
# 633  Data refers to a 5-year period preceding the r...
# 634  Data refers to a 5-year period preceding the r...
# 635                                                NaN
# 636  Data refers to a 5-year period preceding the r...
#
#                                                 Source
# 632  United Nations Population Division, New York, ...
# 633  United Nations Population Division, New York, ...
# 634  United Nations Statistics Division, New York, ...
# 635  World Health Organization (WHO), the United Na...
# 636  United Nations Population Division, New York, ...

# %% [markdown]
# ### Life expectancy at birth (females, years)

# %%
LE_females = Life_Expectancy[Life_Expectancy.Series == "Life expectancy at birth for females (years)" ]
LE_females = LE_females.rename(columns={'Value': 'Life expectancy at birth (females, years)'})
LE_females = pd.DataFrame(LE_females[['country', 'Life expectancy at birth (females, years)']])
LE_females.head()
# Out:
#                  country Life expectancy at birth (females, years)
# 638          Afghanistan                                      63.8
# 659              Albania                                      80.0
# 680              Algeria                                      76.7
# 707               Angola                                      60.5
# 731  Antigua and Barbuda                                      77.4

# %% [markdown]
# ### Life expectancy at birth (males, years)

# %%
LE_males = Life_Expectancy[Life_Expectancy.Series == "Life expectancy at birth for males (years)" ]
LE_males = LE_males.rename(columns={'Value': 'Life expectancy at birth (males, years)'})
LE_males = pd.DataFrame(LE_males[['country', 'Life expectancy at birth (males, years)']])
LE_males.head()
# Out:
#                  country Life expectancy at birth (males, years)
# 637          Afghanistan                                    60.9
# 658              Albania                                    75.2
# 679              Algeria                                    74.4
# 706               Angola                                    55.2
# 730  Antigua and Barbuda                                    74.8

# %% [markdown]
# ## Drinking Water & Sanitation

# %%
Water_Sanitation = pd.read_csv('Water_Sanitation.csv', encoding = "ISO-8859-1")
new_header = Water_Sanitation.iloc[0] #grab the first row for the header
Water_Sanitation = Water_Sanitation[1:] #take the data less the header row
Water_Sanitation.columns = new_header #set the header row as the df header
Water_Sanitation.head()
# Out:
# 0 Region/Country/Area                            NaN  Year  \
# 1                   1  Total, all countries or areas  2010
# 2                   1  Total, all countries or areas  2010
# 3                   1  Total, all countries or areas  2010
# 4                   1  Total, all countries or areas  2010
# 5                   1  Total, all countries or areas  2010
#
# 0                                             Series Value Footnotes  \
# 1  Safely managed drinking water sources, urban (...  84.0       NaN
# 2  Safely managed drinking water sources, rural (...  46.3       NaN
# 3  Safely managed drinking water sources, total (...  65.8       NaN
# 4  Safely managed sanitation facilities, urban (P...  51.6       NaN
# 5  Safely managed sanitation facilities, rural (P...  27.5       NaN
#
# 0                                             Source
# 1  World Health Organization (WHO) and United Nat...
# 2  World Health Organization (WHO) and United Nat...
# 3  World Health Organization (WHO) and United Nat...
# 4  World Health Organization (WHO) and United Nat...
# 5  World Health Organization (WHO) and United Nat...

# %%
# Remove duplicate column name that caused columns names to shift left
cols = list(Water_Sanitation.columns)
cols[1] = 'country'
Water_Sanitation.columns = cols
Water_Sanitation.head()
# Out:
#   Region/Country/Area                        country  Year  \
# 1                   1  Total, all countries or areas  2010
# 2                   1  Total, all countries or areas  2010
# 3                   1  Total, all countries or areas  2010
# 4                   1  Total, all countries or areas  2010
# 5                   1  Total, all countries or areas  2010
#
#                                               Series Value Footnotes  \
# 1  Safely managed drinking water sources, urban (...  84.0       NaN
# 2  Safely managed drinking water sources, rural (...  46.3       NaN
# 3  Safely managed drinking water sources, total (...  65.8       NaN
# 4  Safely managed sanitation facilities, urban (P...  51.6       NaN
# 5  Safely managed sanitation facilities, rural (P...  27.5       NaN
#
#                                               Source
# 1  World Health Organization (WHO) and United Nat...
# 2  World Health Organization (WHO) and United Nat...
# 3  World Health Organization (WHO) and United Nat...
# 4  World Health Organization (WHO) and United Nat...
# 5  World Health Organization (WHO) and United Nat...

# %%
for i in continents:
    Water_Sanitation= Water_Sanitation[Water_Sanitation['country'].str.contains(i)==False]
    
Water_Sanitation=Water_Sanitation[Water_Sanitation['Year'].str.contains('2015')!=False]
Water_Sanitation.head()
# Out:
#     Region/Country/Area      country  Year  \
# 365                   4  Afghanistan  2015
# 366                   4  Afghanistan  2015
# 367                   4  Afghanistan  2015
# 375                   8      Albania  2015
# 376                   8      Albania  2015
#
#                                                 Series Value Footnotes  \
# 365  Safely managed drinking water sources, urban (...  32.4       NaN
# 366  Safely managed drinking water sources, rural (...  20.4       NaN
# 367  Safely managed drinking water sources, total (...  23.4       NaN
# 375  Safely managed drinking water sources, total (...  70.6       NaN
# 376  Safely managed sanitation facilities, urban (P...  43.5       NaN
#
#                                                 Source
# 365  World Health Organization (WHO) and United Nat...
# 366  World Health Organization (WHO) and United Nat...
# 367  World Health Organization (WHO) and United Nat...
# 375  World Health Organization (WHO) and United Nat...
# 376  World Health Organization (WHO) and United Nat...

# %% [markdown]
# ### Pop. using improved drinking water (urban, %)

# %%
water_urban = Water_Sanitation[Water_Sanitation.Series == "Safely managed drinking water sources, urban (Proportion of population with access)" ]
water_urban  = water_urban .rename(columns={'Value': 'Pop. using improved drinking water (urban, %)'})
water_urban = pd.DataFrame(water_urban[['country', 'Pop. using improved drinking water (urban, %)']])
water_urban.head()
# Out:
#          country Pop. using improved drinking water (urban, %)
# 365  Afghanistan                                          32.4
# 389      Algeria                                          79.5
# 434    Australia                                          99.0
# 455   Azerbaijan                                          95.5
# 481   Bangladesh                                          46.9

# %% [markdown]
# ### Pop. using improved drinking water (rural, %)

# %%
water_rural = Water_Sanitation[Water_Sanitation.Series == "Safely managed drinking water sources, rural (Proportion of population with access)" ]
water_rural = water_rural .rename(columns={'Value': 'Pop. using improved drinking water (rural, %)'})
water_rural = pd.DataFrame(water_rural[['country', 'Pop. using improved drinking water (rural, %)']])
water_rural .head()
# Out:
#          country Pop. using improved drinking water (rural, %)
# 366  Afghanistan                                          20.4
# 390      Algeria                                          65.9
# 456   Azerbaijan                                          72.2
# 482   Bangladesh                                          61.2
# 518       Bhutan                                          27.2

# %% [markdown]
# ### Pop. using improved sanitation facilities (urban, %)

# %%
sanitation_urban = Water_Sanitation[Water_Sanitation.Series == "Safely managed sanitation facilities, urban (Proportion of population with access)"]
sanitation_urban  = sanitation_urban.rename(columns={'Value': 'Pop. using improved sanitation facilities (urban, %)'})
sanitation_urban = pd.DataFrame(sanitation_urban[['country', 'Pop. using improved sanitation facilities (urban, %)']])
sanitation_urban.head()
# Out:
#        country Pop. using improved sanitation facilities (urban, %)
# 376    Albania                                               43.5
# 392    Algeria                                               17.0
# 409    Andorra                                              100.0
# 418  Argentina                                               46.7
# 427    Armenia                                               62.0

# %% [markdown]
# ### Pop. using improved sanitation facilities (rural, %)

# %%
sanitation_rural = Water_Sanitation[Water_Sanitation.Series == "Safely managed sanitation facilities, rural (Proportion of population with access)" ]
sanitation_rural = sanitation_rural.rename(columns={'Value': 'Pop. using improved sanitation facilities (rural, %)'})
sanitation_rural= pd.DataFrame(sanitation_rural[['country', 'Pop. using improved sanitation facilities (rural, %)']])
sanitation_rural.head()
# Out:
#         country Pop. using improved sanitation facilities (rural, %)
# 377     Albania                                               50.1
# 393     Algeria                                               23.1
# 410     Andorra                                              100.0
# 444     Austria                                               99.2
# 485  Bangladesh                                               34.5

# %% [markdown]
# ## Population Age

# %%
Age = pd.read_csv('Population_Density.csv', encoding = "ISO-8859-1")
new_header = Age.iloc[0] #grab the first row for the header
Age = Age[1:] #take the data less the header row
Age.columns = new_header #set the header row as the df header
Age.head()
# Out:
# 0 Region/Country/Area                            NaN  Year  \
# 1                   1  Total, all countries or areas  2010
# 2                   1  Total, all countries or areas  2010
# 3                   1  Total, all countries or areas  2010
# 4                   1  Total, all countries or areas  2010
# 5                   1  Total, all countries or areas  2010
#
# 0                                             Series     Value Footnotes  \
# 1           Population mid-year estimates (millions)  6,956.82       NaN
# 2  Population mid-year estimates for males (milli...  3,507.70       NaN
# 3  Population mid-year estimates for females (mil...  3,449.12       NaN
# 4                  Sex ratio (males per 100 females)     101.7       NaN
# 5     Population aged 0 to 14 years old (percentage)        27       NaN
#
# 0                                             Source
# 1  United Nations Population Division, New York, ...
# 2  United Nations Population Division, New York, ...
# 3  United Nations Population Division, New York, ...
# 4  United Nations Population Division, New York, ...
# 5  United Nations Population Division, New York, ...

# %%
# Remove duplicate column name that caused columns names to shift left
cols = list(Age.columns)
cols[1] = 'country'
Age.columns = cols

# %%
for i in continents:
    Age= Age[Age['country'].str.contains(i)==False]

Age=Age[Age['Year'].str.contains('2015')!=False]
Age.head()
# Out:
#     Region/Country/Area      country  Year  \
# 938                   4  Afghanistan  2015
# 939                   4  Afghanistan  2015
# 940                   4  Afghanistan  2015
# 941                   4  Afghanistan  2015
# 942                   4  Afghanistan  2015
#
#                                                 Series  Value Footnotes  \
# 938           Population mid-year estimates (millions)  34.41       NaN
# 939  Population mid-year estimates for males (milli...  17.69       NaN
# 940  Population mid-year estimates for females (mil...  16.73       NaN
# 941                  Sex ratio (males per 100 females)  105.7       NaN
# 942     Population aged 0 to 14 years old (percentage)   44.9       NaN
#
#                                                 Source
# 938  United Nations Population Division, New York, ...
# 939  United Nations Population Division, New York, ...
# 940  United Nations Population Division, New York, ...
# 941  United Nations Population Division, New York, ...
# 942  United Nations Population Division, New York, ...

# %% [markdown]
# ### Population age distribution (0-14 years, %)

# %%
Age_0 = Age[Age.Series == "Population aged 0 to 14 years old (percentage)" ]
Age_0= Age_0.rename(columns={'Value': 'Population age distribution (0-14 years, %)'})
Age_0 = pd.DataFrame(Age_0[['country', 'Population age distribution (0-14 years, %)']])
Age_0.head()
# Out:
#                   country Population age distribution (0-14 years, %)
# 942           Afghanistan                                        44.9
# 972               Albania                                        18.7
# 1002              Algeria                                        28.7
# 1052               Angola                                        47.1
# 1092  Antigua and Barbuda                                        22.6

# %% [markdown]
# ### Population age distribution (60+ years, %)

# %%
Age_60 = Age[Age.Series == "Population aged 60+ years old (percentage)" ]
Age_60= Age_60.rename(columns={'Value': 'Population age distribution (60+ years, %)'})
Age_60 = pd.DataFrame(Age_60[['country', 'Population age distribution (60+ years, %)']])
Age_60.head()
# Out:
#                   country Population age distribution (60+ years, %)
# 943           Afghanistan                                          4
# 973               Albania                                       17.9
# 1003              Algeria                                        8.9
# 1053               Angola                                        3.6
# 1093  Antigua and Barbuda                                       12.1

# %%
frames = [Upop, Infant_Fertility, Internet_Usage, Employment_Services, Employment_Agriculture, GDP, 
          Infant_Mortality, Secondary_female, Secondary_male, Tertiary_female, Tertiary_male, LE_females, 
          LE_males, water_urban, water_rural, sanitation_urban, sanitation_rural, Age_0, Age_60]

Data_2015 = pd.DataFrame(GVA[['country', 'Economy: Agriculture (% of GVA)']])

for i in frames:
    Data_2015 = pd.merge(i, Data_2015, on="country", how='outer')
    
Data_2015.columns
# Out:
# Index(['country', 'Population age distribution (60+ years, %)',
#        'Population age distribution (0-14 years, %)',
#        'Pop. using improved sanitation facilities (rural, %)',
#        'Pop. using improved sanitation facilities (urban, %)',
#        'Pop. using improved drinking water (rural, %)',
#        'Pop. using improved drinking water (urban, %)',
#        'Life expectancy at birth (males, years)',
#        'Life expectancy at birth (females, years)',
#        'Education: Tertiary gross enrol. ratio (male per 100 pop.)',
#        'Education: Tertiary gross enrol. ratio (female per 100 pop.)',
#        'Education: Secondary gross enrol. ratio (male per 100 pop.)',
#        'Education: Secondary gross enrol. ratio (female per 100 pop.)',
#        'Infant mortality rate (per 1000 live births',
#        'GDP per capita (current US$)',
#        'Employment: Agriculture (% of employed)',
#        'Employment: Services (% of employed)',
#        'Individuals using the Internet (per 100 inhabitants)',
#        'Fertility rate, total (live births per woman)',
#        'Urban population (% of total population)',
#        'Economy: Agriculture (% of GVA)'],
#       dtype='object')

# %% [markdown]
# ## Merge with 2015 Happiness Score

# %%
happiness_2015 = pd.read_csv('happiness_2015.csv')
happiness_2015 = happiness_2015.rename(columns={'Country': 'country', 'Happiness Score': 'happiness.score'})
happiness_2015 = pd.DataFrame(happiness_2015[['country', 'happiness.score']])

# %%
happiness_2015['country'].unique()
# Out:
# array(['Switzerland', 'Iceland', 'Denmark', 'Norway', 'Canada', 'Finland',
#        'Netherlands', 'Sweden', 'New Zealand', 'Australia', 'Israel',
#        'Costa Rica', 'Austria', 'Mexico', 'United States', 'Brazil',
#        'Luxembourg', 'Ireland', 'Belgium', 'United Arab Emirates',
#        'United Kingdom', 'Oman', 'Venezuela', 'Singapore', 'Panama',
#        'Germany', 'Chile', 'Qatar', 'France', 'Argentina',
#        'Czech Republic', 'Uruguay', 'Colombia', 'Thailand',
#        'Saudi Arabia', 'Spain', 'Malta', 'Taiwan', 'Kuwait', 'Suriname',
#        'Trinidad and Tobago', 'El Salvador', 'Guatemala', 'Uzbekistan',
#        'Slovakia', 'Japan', 'South Korea', 'Ecuador', 'Bahrain', 'Italy',
#        'Bolivia', 'Moldova', 'Paraguay', 'Kazakhstan', 'Slovenia',
#        'Lithuania', 'Nicaragua', 'Peru', 'Belarus', 'Poland', 'Malaysia',
#        'Croatia', 'Libya', 'Russia', 'Jamaica', 'North Cyprus', 'Cyprus',
#        'Algeria', 'Kosovo', 'Turkmenistan', 'Mauritius', 'Hong Kong',
#        'Estonia', 'Indonesia', 'Vietnam', 'Turkey', 'Kyrgyzstan',
#        'Nigeria', 'Bhutan', 'Azerbaijan', 'Pakistan', 'Jordan',
#        'Montenegro', 'China', 'Zambia', 'Romania', 'Serbia', 'Portugal',
#        'Latvia', 'Philippines', 'Somaliland region', 'Morocco',
#        'Macedonia', 'Mozambique', 'Albania', 'Bosnia and Herzegovina',
#        'Lesotho', 'Dominican Republic', 'Laos', 'Mongolia', 'Swaziland',
#        'Greece', 'Lebanon', 'Hungary', 'Honduras', 'Tajikistan',
#        'Tunisia', 'Palestinian Territories', 'Bangladesh', 'Iran',
#        'Ukraine', 'Iraq', 'South Africa', 'Ghana', 'Zimbabwe', 'Liberia',
#        'India', 'Sudan', 'Haiti', 'Congo (Kinshasa)', 'Nepal', 'Ethiopia',
#        'Sierra Leone', 'Mauritania', 'Kenya', 'Djibouti', 'Armenia',
#        'Botswana', 'Myanmar', 'Georgia', 'Malawi', 'Sri Lanka',
#        'Cameroon', 'Bulgaria', 'Egypt', 'Yemen', 'Angola', 'Mali',
#        'Congo (Brazzaville)', 'Comoros', 'Uganda', 'Senegal', 'Gabon',
#        'Niger', 'Cambodia', 'Tanzania', 'Madagascar',
#        'Central African Republic', 'Chad', 'Guinea', 'Ivory Coast',
#        'Burkina Faso', 'Afghanistan', 'Rwanda', 'Benin', 'Syria',
#        'Burundi', 'Togo'], dtype=object)

# %%
Data_2015['country'].unique()
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'Angola',
#        'Antigua and Barbuda', 'Argentina', 'Armenia', 'Aruba',
#        'Australia', 'Austria', 'Azerbaijan', 'Bahamas', 'Bahrain',
#        'Bangladesh', 'Barbados', 'Belarus', 'Belgium', 'Belize', 'Benin',
#        'Bhutan', 'Bolivia (Plurin. State of)', 'Bosnia and Herzegovina',
#        'Botswana', 'Brazil', 'Brunei Darussalam', 'Bulgaria',
#        'Burkina Faso', 'Burundi', 'Cabo Verde', 'Cambodia', 'Cameroon',
#        'Canada', 'Chad', 'Channel Islands', 'Chile', 'China',
#        'China, Hong Kong SAR', 'China, Macao SAR', 'Colombia', 'Comoros',
#        'Congo', 'Costa Rica', 'Côte d\x92Ivoire', 'Croatia', 'Cuba',
#        'Curaçao', 'Cyprus', 'Czechia', "Dem. People's Rep. Korea",
#        'Dem. Rep. of the Congo', 'Denmark', 'Djibouti',
#        'Dominican Republic', 'Ecuador', 'Egypt', 'El Salvador',
#        'Equatorial Guinea', 'Eritrea', 'Estonia', 'Eswatini', 'Ethiopia',
#        'Fiji', 'Finland', 'France', 'French Guiana', 'Gabon', 'Gambia',
#        'Georgia', 'Germany', 'Ghana', 'Greece', 'Grenada', 'Guadeloupe',
#        'Guam', 'Guatemala', 'Guinea', 'Guinea-Bissau', 'Guyana', 'Haiti',
#        'Honduras', 'Hungary', 'Iceland', 'India', 'Indonesia',
#        'Iran (Islamic Republic of)', 'Iraq', 'Ireland', 'Israel', 'Italy',
#        'Jamaica', 'Japan', 'Jordan', 'Kazakhstan', 'Kenya', 'Kiribati',
#        'Kuwait', 'Kyrgyzstan', "Lao People's Dem. Rep.", 'Latvia',
#        'Lebanon', 'Lesotho', 'Liberia', 'Libya', 'Lithuania',
#        'Luxembourg', 'Madagascar', 'Malawi', 'Malaysia', 'Maldives',
#        'Mali', 'Malta', 'Martinique', 'Mauritania', 'Mauritius',
#        'Mayotte', 'Mexico', 'Mongolia', 'Montenegro', 'Morocco',
#        'Mozambique', 'Myanmar', 'Namibia', 'Nepal', 'Netherlands',
#        'New Caledonia', 'New Zealand', 'Nicaragua', 'Niger', 'Nigeria',
#        'North Macedonia', 'Norway', 'Oman', 'Other non-specified areas',
#        'Pakistan', 'Panama', 'Papua New Guinea', 'Paraguay', 'Peru',
#        'Philippines', 'Poland', 'Portugal', 'Puerto Rico', 'Qatar',
#        'Republic of Korea', 'Republic of Moldova', 'Réunion', 'Romania',
#        'Russian Federation', 'Rwanda', 'Saint Lucia',
#        'Saint Vincent & Grenadines', 'Samoa', 'Sao Tome and Principe',
#        'Saudi Arabia', 'Senegal', 'Serbia', 'Seychelles', 'Sierra Leone',
#        'Singapore', 'Slovakia', 'Slovenia', 'Solomon Islands', 'Somalia',
#        'South Sudan', 'Spain', 'Sri Lanka', 'State of Palestine', 'Sudan',
#        'Suriname', 'Sweden', 'Switzerland', 'Syrian Arab Republic',
#        'Tajikistan', 'Thailand', 'Timor-Leste', 'Togo', 'Tonga',
#        'Trinidad and Tobago', 'Tunisia', 'Turkey', 'Turkmenistan',
#        'Uganda', 'Ukraine', 'United Arab Emirates', 'United Kingdom',
#        'United Rep. of Tanzania', 'United States of America',
#        'United States Virgin Islands', 'Uruguay', 'Uzbekistan', 'Vanuatu',
#        'Venezuela (Boliv. Rep. of)', 'Viet Nam', 'Western Sahara',
#        'Yemen', 'Zambia', 'Zimbabwe', 'Andorra', 'Tuvalu', 'Monaco',
#        'Palau', 'Wallis and Futuna Islands', 'Gibraltar',
#        'Saint Barthélemy', 'Saint Martin (French part)', 'Bermuda',
#        'British Virgin Islands', 'Cook Islands', 'Dominica',
#        'Liechtenstein', 'Marshall Islands', 'Niue',
#        'Saint Kitts and Nevis', 'Turks and Caicos Islands', 'Anguilla',
#        'Cayman Islands', 'Greenland', 'Kosovo', 'Montserrat', 'Nauru',
#        'San Marino', 'Sint Maarten (Dutch part)', 'Zanzibar',
#        'Falkland Islands (Malvinas)', 'Faroe Islands', 'American Samoa',
#        'Bonaire, St. Eustatius & Saba', 'Holy See', 'Isle of Man',
#        'Northern Mariana Islands', 'Saint Helena',
#        'Saint Pierre and Miquelon', 'TFYR of Macedonia', 'Tokelau'],
#       dtype=object)

# %%
for i in happiness_2015['country'].unique():
    if i not in Data_2015['country'].unique():
        print(i)
# Out:
# United States
# Venezuela
# Czech Republic
# Taiwan
# South Korea
# Bolivia
# Moldova
# Russia
# North Cyprus
# Hong Kong
# Vietnam
# Somaliland region
# Macedonia
# Laos
# Swaziland
# Palestinian Territories
# Iran
# South Africa
# Congo (Kinshasa)
# Congo (Brazzaville)
# Tanzania
# Central African Republic
# Ivory Coast
# Syria

# %%
Data_2015.loc[Data_2015.country == 'United States of America', 'country'] = "United States"
Data_2015.loc[Data_2015.country == 'Venezuela (Boliv. Rep. of)', 'country'] = "Venezuela"
Data_2015.loc[Data_2015.country == 'Czechia', 'country'] = "Czech Republic"
Data_2015.loc[Data_2015.country == 'Republic of Korea', 'country'] = "South Korea"
Data_2015.loc[Data_2015.country == 'Bolivia (Plurin. State of)', 'country'] = "Bolivia"
Data_2015.loc[Data_2015.country == 'Republic of Moldova', 'country'] = "Moldova"
Data_2015.loc[Data_2015.country == 'Russian Federation', 'country'] = "Russia"
Data_2015.loc[Data_2015.country == 'China, Hong Kong SAR', 'country'] = "Hong Kong"
Data_2015.loc[Data_2015.country == 'Viet Nam', 'country'] = "Vietnam"
Data_2015.loc[Data_2015.country == "Lao People's Dem. Rep.", 'country'] = "Laos"
Data_2015.loc[Data_2015.country == 'State of Palestine', 'country'] = "Palestinian Territories"
Data_2015.loc[Data_2015.country == 'Iran (Islamic Republic of)', 'country'] = "Iran"
Data_2015.loc[Data_2015.country == 'Dem. Rep. of the Congo', 'country'] = "Congo (Kinshasa)"
Data_2015.loc[Data_2015.country == 'Congo', 'country'] = "Congo (Brazzaville)"
Data_2015.loc[Data_2015.country == 'United Rep. of Tanzania', 'country'] = "Tanzania"
Data_2015.loc[Data_2015.country == 'Côte dIvoire', 'country'] = "Ivory Coast"
Data_2015.loc[Data_2015.country == 'Syrian Arab Republic', 'country'] = "Syria"

# NO UN Data
# Taiwan
# North Cyprus
# Somaliland region
# Macedonia
# Swaziland
# South Africa
# Central African Republic

# %%
Fdata_2015 = pd.merge(Data_2015, happiness_2015, on="country", how='inner')

# %%
Fdata_2015
# Out:
#          country Population age distribution (60+ years, %)  \
# 0    Afghanistan                                          4
# 1        Albania                                       17.9
# 2        Algeria                                        8.9
# 3         Angola                                        3.6
# 4      Argentina                                       14.9
# ..           ...                                        ...
# 146      Vietnam                                       10.2
# 147        Yemen                                        4.4
# 148       Zambia                                        3.3
# 149     Zimbabwe                                        4.4
# 150       Kosovo                                        NaN
#
#     Population age distribution (0-14 years, %)  \
# 0                                          44.9
# 1                                          18.7
# 2                                          28.7
# 3                                          47.1
# 4                                          25.2
# ..                                          ...
# 146                                          23
# 147                                        40.7
# 148                                        46.2
# 149                                        42.6
# 150                                         NaN
#
#     Pop. using improved sanitation facilities (rural, %)  \
# 0                                                  NaN
# 1                                                 50.1
# 2                                                 23.1
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 146                                                NaN
# 147                                                NaN
# 148                                               19.6
# 149                                               31.1
# 150                                                NaN
#
#     Pop. using improved sanitation facilities (urban, %)  \
# 0                                                  NaN
# 1                                                 43.5
# 2                                                 17.0
# 3                                                  NaN
# 4                                                 46.7
# ..                                                 ...
# 146                                                NaN
# 147                                               61.4
# 148                                                NaN
# 149                                               19.0
# 150                                                NaN
#
#     Pop. using improved drinking water (rural, %)  \
# 0                                            20.4
# 1                                             NaN
# 2                                            65.9
# 3                                             NaN
# 4                                             NaN
# ..                                            ...
# 146                                           NaN
# 147                                           NaN
# 148                                           NaN
# 149                                          14.0
# 150                                           NaN
#
#     Pop. using improved drinking water (urban, %)  \
# 0                                            32.4
# 1                                             NaN
# 2                                            79.5
# 3                                             NaN
# 4                                             NaN
# ..                                            ...
# 146                                           NaN
# 147                                           NaN
# 148                                          50.1
# 149                                          64.5
# 150                                           NaN
#
#     Life expectancy at birth (males, years)  \
# 0                                      60.9
# 1                                      75.2
# 2                                      74.4
# 3                                      55.2
# 4                                      72.2
# ..                                      ...
# 146                                    70.8
# 147                                    64.3
# 148                                    57.0
# 149                                    54.9
# 150                                     NaN
#
#     Life expectancy at birth (females, years)  \
# 0                                        63.8
# 1                                        80.0
# 2                                        76.7
# 3                                        60.5
# 4                                        79.0
# ..                                        ...
# 146                                      79.1
# 147                                      67.7
# 148                                      61.5
# 149                                      58.3
# 150                                       NaN
#
#     Education: Tertiary gross enrol. ratio (male per 100 pop.)  ...  \
# 0                                                 52.6          ...
# 1                                                 99.6          ...
# 2                                                  NaN          ...
# 3                                                  NaN          ...
# 4                                                 79.4          ...
# ..                                                 ...          ...
# 146                                                NaN          ...
# 147                                                NaN          ...
# 148                                                NaN          ...
# 149                                                NaN          ...
# 150                                                NaN          ...
#
#     Education: Secondary gross enrol. ratio (female per 100 pop.)  \
# 0                                                 36.8
# 1                                                 95.1
# 2                                                  NaN
# 3                                                  NaN
# 4                                                110.2
# ..                                                 ...
# 146                                                NaN
# 147                                                NaN
# 148                                                NaN
# 149                                                NaN
# 150                                                NaN
#
#     Infant mortality rate (per 1000 live births GDP per capita (current US$)  \
# 0                                          60.1                          544
# 1                                           9.2                         3939
# 2                                          24.9                         4178
# 3                                          78.2                         4167
# 4                                          12.1                        14971
# ..                                          ...                          ...
# 146                                        17.9                         2085
# 147                                        43.3                         1006
# 148                                        53.3                         1314
# 149                                        51.2                         1445
# 150                                         NaN                         3615
#
#     Employment: Agriculture (% of employed)  \
# 0                                      47.1
# 1                                      41.4
# 2                                      10.3
# 3                                      50.6
# 4                                       0.3
# ..                                      ...
# 146                                    44.0
# 147                                    29.2
# 148                                    51.7
# 149                                    67.2
# 150                                     NaN
#
#     Employment: Services (% of employed)  \
# 0                                   35.8
# 1                                   40.0
# 2                                   58.7
# 3                                   40.8
# 4                                   76.1
# ..                                   ...
# 146                                 33.2
# 147                                 58.0
# 148                                 37.7
# 149                                 25.7
# 150                                  NaN
#
#     Individuals using the Internet (per 100 inhabitants)  \
# 0                                                  8.3
# 1                                                 63.3
# 2                                                 38.2
# 3                                                 12.4
# 4                                                   68
# ..                                                 ...
# 146                                                 45
# 147                                               24.1
# 148                                                 21
# 149                                               22.7
# 150                                                NaN
#
#     Fertility rate, total (live births per woman)  \
# 0                                             5.4
# 1                                             1.7
# 2                                             3.0
# 3                                             6.0
# 4                                             2.3
# ..                                            ...
# 146                                           2.0
# 147                                           4.4
# 148                                           5.2
# 149                                           4.1
# 150                                           NaN
#
#     Urban population (% of total population) Economy: Agriculture (% of GVA)  \
# 0                                       24.8                            27.3
# 1                                       57.4                            22.5
# 2                                       70.8                            12.1
# 3                                       63.4                             9.1
# 4                                       91.5                             6.1
# ..                                       ...                             ...
# 146                                     33.8                            18.9
# 147                                     34.8                            18.2
# 148                                     41.9                             5.3
# 149                                     32.4                             9.3
# 150                                      NaN                            12.6
#
#     happiness.score
# 0             3.575
# 1             4.959
# 2             5.605
# 3             4.033
# 4             6.574
# ..              ...
# 146           5.360
# 147           4.077
# 148           5.129
# 149           4.610
# 150           5.589
#
# [151 rows x 22 columns]

# %%
sb.heatmap(Fdata_2015.isnull(),cbar=False,cmap='viridis')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # 2017 Data

# %%
happiness_2017 = pd.read_csv('happiness_2017.csv')
data_2017 = pd.read_csv('country_profile_variables.csv')

# %%
# Remove duplicate column name that caused columns names to shift left
cols = list(data_2017.columns)
cols.remove('Mobile-cellular subscriptions (per 100 inhabitants).1')
data_2017.columns = cols + ['remove']
data_2017 = data_2017.drop(columns=['remove'])

# %%
happiness_2017 = pd.DataFrame(happiness_2017[['Country', 'Happiness.Score']])
happiness_2017 = happiness_2017.rename(columns={'Country': 'country', 'Happiness.Score': 'happiness.score'})
happiness_2017
# Out:
#                       country  happiness.score
# 0                      Norway            7.537
# 1                     Denmark            7.522
# 2                     Iceland            7.504
# 3                 Switzerland            7.494
# 4                     Finland            7.469
# ..                        ...              ...
# 150                    Rwanda            3.471
# 151                     Syria            3.462
# 152                  Tanzania            3.349
# 153                   Burundi            2.905
# 154  Central African Republic            2.693
#
# [155 rows x 2 columns]

# %%
happiness_2017['country'].unique()
# Out:
# array(['Norway', 'Denmark', 'Iceland', 'Switzerland', 'Finland',
#        'Netherlands', 'Canada', 'New Zealand', 'Sweden', 'Australia',
#        'Israel', 'Costa Rica', 'Austria', 'United States', 'Ireland',
#        'Germany', 'Belgium', 'Luxembourg', 'United Kingdom', 'Chile',
#        'United Arab Emirates', 'Brazil', 'Czech Republic', 'Argentina',
#        'Mexico', 'Singapore', 'Malta', 'Uruguay', 'Guatemala', 'Panama',
#        'France', 'Thailand', 'Taiwan Province of China', 'Spain', 'Qatar',
#        'Colombia', 'Saudi Arabia', 'Trinidad and Tobago', 'Kuwait',
#        'Slovakia', 'Bahrain', 'Malaysia', 'Nicaragua', 'Ecuador',
#        'El Salvador', 'Poland', 'Uzbekistan', 'Italy', 'Russia', 'Belize',
#        'Japan', 'Lithuania', 'Algeria', 'Latvia', 'South Korea',
#        'Moldova', 'Romania', 'Bolivia', 'Turkmenistan', 'Kazakhstan',
#        'North Cyprus', 'Slovenia', 'Peru', 'Mauritius', 'Cyprus',
#        'Estonia', 'Belarus', 'Libya', 'Turkey', 'Paraguay',
#        'Hong Kong S.A.R., China', 'Philippines', 'Serbia', 'Jordan',
#        'Hungary', 'Jamaica', 'Croatia', 'Kosovo', 'China', 'Pakistan',
#        'Indonesia', 'Venezuela', 'Montenegro', 'Morocco', 'Azerbaijan',
#        'Dominican Republic', 'Greece', 'Lebanon', 'Portugal',
#        'Bosnia and Herzegovina', 'Honduras', 'Macedonia', 'Somalia',
#        'Vietnam', 'Nigeria', 'Tajikistan', 'Bhutan', 'Kyrgyzstan',
#        'Nepal', 'Mongolia', 'South Africa', 'Tunisia',
#        'Palestinian Territories', 'Egypt', 'Bulgaria', 'Sierra Leone',
#        'Cameroon', 'Iran', 'Albania', 'Bangladesh', 'Namibia', 'Kenya',
#        'Mozambique', 'Myanmar', 'Senegal', 'Zambia', 'Iraq', 'Gabon',
#        'Ethiopia', 'Sri Lanka', 'Armenia', 'India', 'Mauritania',
#        'Congo (Brazzaville)', 'Georgia', 'Congo (Kinshasa)', 'Mali',
#        'Ivory Coast', 'Cambodia', 'Sudan', 'Ghana', 'Ukraine', 'Uganda',
#        'Burkina Faso', 'Niger', 'Malawi', 'Chad', 'Zimbabwe', 'Lesotho',
#        'Angola', 'Afghanistan', 'Botswana', 'Benin', 'Madagascar',
#        'Haiti', 'Yemen', 'South Sudan', 'Liberia', 'Guinea', 'Togo',
#        'Rwanda', 'Syria', 'Tanzania', 'Burundi',
#        'Central African Republic'], dtype=object)

# %%
data_2017['country'].unique()
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'American Samoa', 'Andorra',
#        'Angola', 'Anguilla', 'Antigua and Barbuda', 'Argentina',
#        'Armenia', 'Aruba', 'Australia', 'Austria', 'Azerbaijan',
#        'Bahamas', 'Bahrain', 'Bangladesh', 'Barbados', 'Belarus',
#        'Belgium', 'Belize', 'Benin', 'Bermuda', 'Bhutan',
#        'Bolivia (Plurinational State of)',
#        'Bonaire, Sint Eustatius and Saba', 'Bosnia and Herzegovina',
#        'Botswana', 'Brazil', 'British Virgin Islands',
#        'Brunei Darussalam', 'Bulgaria', 'Burkina Faso', 'Burundi',
#        'Cabo Verde', 'Cambodia', 'Cameroon', 'Canada', 'Cayman Islands',
#        'Central African Republic', 'Chad', 'Channel Islands', 'Chile',
#        'China, Hong Kong SAR', 'China, Macao SAR', 'China', 'Colombia',
#        'Comoros', 'Congo', 'Cook Islands', 'Costa Rica', 'Croatia',
#        'Cuba', 'Cyprus', 'Czechia',
#        "Democratic People's Republic of Korea",
#        'Democratic Republic of the Congo', 'Denmark', 'Djibouti',
#        'Dominica', 'Dominican Republic', 'Ecuador', 'Egypt',
#        'El Salvador', 'Equatorial Guinea', 'Eritrea', 'Estonia',
#        'Ethiopia', 'Falkland Islands (Malvinas)', 'Faroe Islands', 'Fiji',
#        'Finland', 'France', 'French Guiana', 'French Polynesia', 'Gabon',
#        'Gambia', 'Georgia', 'Germany', 'Ghana', 'Gibraltar', 'Greece',
#        'Greenland', 'Grenada', 'Guadeloupe', 'Guam', 'Guatemala',
#        'Guinea-Bissau', 'Guinea', 'Guyana', 'Haiti', 'Holy See',
#        'Honduras', 'Hungary', 'Iceland', 'India', 'Indonesia',
#        'Iran (Islamic Republic of)', 'Iraq', 'Ireland', 'Isle of Man',
#        'Israel', 'Italy', 'Jamaica', 'Japan', 'Jordan', 'Kazakhstan',
#        'Kenya', 'Kiribati', 'Kuwait', 'Kyrgyzstan',
#        "Lao People's Democratic Republic", 'Latvia', 'Lebanon', 'Lesotho',
#        'Liberia', 'Libya', 'Liechtenstein', 'Lithuania', 'Luxembourg',
#        'Madagascar', 'Malawi', 'Malaysia', 'Maldives', 'Mali', 'Malta',
#        'Marshall Islands', 'Martinique', 'Mauritania', 'Mauritius',
#        'Mayotte', 'Mexico', 'Micronesia (Federated States of)', 'Monaco',
#        'Mongolia', 'Montenegro', 'Montserrat', 'Morocco', 'Mozambique',
#        'Myanmar', 'Namibia', 'Nauru', 'Nepal', 'Netherlands',
#        'New Caledonia', 'New Zealand', 'Nicaragua', 'Niger', 'Nigeria',
#        'Niue', 'Northern Mariana Islands', 'Norway', 'Oman', 'Pakistan',
#        'Palau', 'Panama', 'Papua New Guinea', 'Paraguay', 'Peru',
#        'Philippines', 'Poland', 'Portugal', 'Puerto Rico', 'Qatar',
#        'Republic of Korea', 'Republic of Moldova', 'Romania',
#        'Russian Federation', 'Rwanda', 'Saint Helena',
#        'Saint Kitts and Nevis', 'Saint Lucia',
#        'Saint Pierre and Miquelon', 'Saint Vincent and the Grenadines',
#        'Samoa', 'San Marino', 'Sao Tome and Principe', 'Saudi Arabia',
#        'Senegal', 'Serbia', 'Seychelles', 'Sierra Leone', 'Singapore',
#        'Sint Maarten (Dutch part)', 'Slovakia', 'Slovenia',
#        'Solomon Islands', 'Somalia', 'South Africa', 'South Sudan',
#        'Spain', 'Sri Lanka', 'State of Palestine', 'Sudan', 'Suriname',
#        'Swaziland', 'Sweden', 'Switzerland', 'Syrian Arab Republic',
#        'Tajikistan', 'Thailand',
#        'The former Yugoslav Republic of Macedonia', 'Timor-Leste', 'Togo',
#        'Tokelau', 'Tonga', 'Trinidad and Tobago', 'Tunisia', 'Turkey',
#        'Turkmenistan', 'Turks and Caicos Islands', 'Tuvalu', 'Uganda',
#        'Ukraine', 'United Arab Emirates', 'United Kingdom',
#        'United Republic of Tanzania', 'United States of America',
#        'United States Virgin Islands', 'Uruguay', 'Uzbekistan', 'Vanuatu',
#        'Venezuela (Bolivarian Republic of)', 'Viet Nam',
#        'Wallis and Futuna Islands', 'Western Sahara', 'Yemen', 'Zambia',
#        'Zimbabwe'], dtype=object)

# %%
for i in happiness_2017['country'].unique():
    if i not in data_2017['country'].unique():
        print(i)
# Out:
# United States
# Czech Republic
# Taiwan Province of China
# Russia
# South Korea
# Moldova
# Bolivia
# North Cyprus
# Hong Kong S.A.R., China
# Kosovo
# Venezuela
# Macedonia
# Vietnam
# Palestinian Territories
# Iran
# Congo (Brazzaville)
# Congo (Kinshasa)
# Ivory Coast
# Syria
# Tanzania

# %%
data_2017.loc[data_2017.country == 'United States of America', 'country'] = "United States"
data_2017.loc[data_2017.country == 'Czechia', 'country'] = "Czech Republic"
# taiwan
data_2017.loc[data_2017.country == 'Russian Federation', 'country'] = "Russia"
data_2017.loc[data_2017.country == 'Republic of Korea', 'country'] = "South Korea"
data_2017.loc[data_2017.country == 'Republic of Moldova', 'country'] = "Moldova"
data_2017.loc[data_2017.country == 'Bolivia (Plurinational State of)', 'country'] = "Bolivia"
# north cyprus
data_2017.loc[data_2017.country == 'China, Hong Kong SAR', 'country'] = "Hong Kong S.A.R., China"
# kosovo
data_2017.loc[data_2017.country == 'Venezuela (Bolivarian Republic of)', 'country'] = "Venezuela"
data_2017.loc[data_2017.country == 'The former Yugoslav Republic of Macedonia', 'country'] = "Macedonia"
data_2017.loc[data_2017.country == 'Viet Nam', 'country'] = "Vietnam"
data_2017.loc[data_2017.country == 'State of Palestine', 'country'] = "Palestinian Territories"
data_2017.loc[data_2017.country == 'Iran (Islamic Republic of)', 'country'] = "Iran"
data_2017.loc[data_2017.country == 'Democratic Republic of the Congo', 'country'] = "Congo (Kinshasa)"
data_2017.loc[data_2017.country == 'Congo', 'country'] = "Congo (Brazzaville)"
# ivory coast
data_2017.loc[data_2017.country == 'Syrian Arab Republic', 'country'] = "Syria"
data_2017.loc[data_2017.country == 'United Republic of Tanzania', 'country'] = "Tanzania"

# %%
data_2017[['Education: Secondary gross enrol. ratio (female per 100 pop.)','Education: Secondary gross enrol. ratio (male per 100 pop.)']] = data_2017['Education: Secondary gross enrol. ratio (f/m per 100 pop.)'].str.split(pat ='/', expand= True)
data_2017[['Education: Tertiary gross enrol. ratio (female per 100 pop.)','Education: Tertiary gross enrol. ratio (male per 100 pop.)']] = data_2017['Education: Tertiary gross enrol. ratio (f/m per 100 pop.)'].str.split(pat ='/', expand= True)
data_2017[['Life expectancy at birth (females, years)','Life expectancy at birth (males, years)']] = data_2017['Life expectancy at birth (females/males, years)'].str.split(pat ='/', expand= True)
data_2017[['Pop. using improved drinking water (urban, %)','Pop. using improved drinking water (rural, %)']] = data_2017['Pop. using improved drinking water (urban/rural, %)'].str.split(pat ='/', expand= True)
data_2017[['Pop. using improved sanitation facilities (urban, %)','Pop. using improved sanitation facilities (rural, %)']] = data_2017['Pop. using improved sanitation facilities (urban/rural, %)'].str.split(pat ='/', expand= True)
data_2017[['Population age distribution (0-14 years, %)','Population age distribution (60+ years, %)']] = data_2017['Population age distribution (0-14 / 60+ years, %)'].str.split(pat ='/', expand= True)
data_2017 = data_2017.drop(columns=['Population age distribution (0-14 / 60+ years, %)'])
data_2017 = data_2017.drop(columns=['Pop. using improved drinking water (urban/rural, %)','Pop. using improved sanitation facilities (urban/rural, %)'])
data_2017 = data_2017.drop(columns=['Life expectancy at birth (females/males, years)'])
data_2017 = data_2017.drop(columns=['Education: Secondary gross enrol. ratio (f/m per 100 pop.)','Education: Tertiary gross enrol. ratio (f/m per 100 pop.)'])

# %%
for col in data_2017.columns:
    data_2017[col].replace({'-99':np.nan},inplace=True)
    data_2017[col].replace({-99:np.nan},inplace=True)
    data_2017[col].replace({'...':np.nan},inplace=True)
    data_2017[col].replace({'~0':0},inplace=True)
    data_2017[col].replace({'~0.0':0},inplace=True)
    data_2017[col].replace({'.../...':np.nan},inplace=True)
    data_2017[col].replace({'-~0.0':0},inplace=True)

# %%
Fdata_2015.columns
# Out:
# Index(['country', 'Population age distribution (60+ years, %)',
#        'Population age distribution (0-14 years, %)',
#        'Pop. using improved sanitation facilities (rural, %)',
#        'Pop. using improved sanitation facilities (urban, %)',
#        'Pop. using improved drinking water (rural, %)',
#        'Pop. using improved drinking water (urban, %)',
#        'Life expectancy at birth (males, years)',
#        'Life expectancy at birth (females, years)',
#        'Education: Tertiary gross enrol. ratio (male per 100 pop.)',
#        'Education: Tertiary gross enrol. ratio (female per 100 pop.)',
#        'Education: Secondary gross enrol. ratio (male per 100 pop.)',
#        'Education: Secondary gross enrol. ratio (female per 100 pop.)',
#        'Infant mortality rate (per 1000 live births',
#        'GDP per capita (current US$)',
#        'Employment: Agriculture (% of employed)',
#        'Employment: Services (% of employed)',
#        'Individuals using the Internet (per 100 inhabitants)',
#        'Fertility rate, total (live births per woman)',
#        'Urban population (% of total population)',
#        'Economy: Agriculture (% of GVA)', 'happiness.score'],
#       dtype='object')

# %%
data_2017.columns
# Out:
# Index(['country', 'Region', 'Surface area (km2)',
#        'Population in thousands (2017)', 'Population density (per km2, 2017)',
#        'Sex ratio (m per 100 f, 2017)',
#        'GDP: Gross domestic product (million current US$)',
#        'GDP growth rate (annual %, const. 2005 prices)',
#        'GDP per capita (current US$)', 'Economy: Agriculture (% of GVA)',
#        'Economy: Industry (% of GVA)',
#        'Economy: Services and other activity (% of GVA)',
#        'Employment: Agriculture (% of employed)',
#        'Employment: Industry (% of employed)',
#        'Employment: Services (% of employed)',
#        'Unemployment (% of labour force)',
#        'Labour force participation (female/male pop. %)',
#        'Agricultural production index (2004-2006=100)',
#        'Food production index (2004-2006=100)',
#        'International trade: Exports (million US$)',
#        'International trade: Imports (million US$)',
#        'International trade: Balance (million US$)',
#        'Balance of payments, current account (million US$)',
#        'Population growth rate (average annual %)',
#        'Urban population (% of total population)',
#        'Urban population growth rate (average annual %)',
#        'Fertility rate, total (live births per woman)',
#        'International migrant stock (000/% of total pop.)',
#        'Refugees and others of concern to UNHCR (in thousands)',
#        'Infant mortality rate (per 1000 live births',
#        'Health: Total expenditure (% of GDP)',
#        'Health: Physicians (per 1000 pop.)',
#        'Education: Government expenditure (% of GDP)',
#        'Education: Primary gross enrol. ratio (f/m per 100 pop.)',
#        'Seats held by women in national parliaments %',
#        'Mobile-cellular subscriptions (per 100 inhabitants)',
#        'Individuals using the Internet (per 100 inhabitants)',
#        'Threatened species (number)', 'Forested area (% of land area)',
#        'CO2 emission estimates (million tons/tons per capita)',
#        'Energy production, primary (Petajoules)',
#        'Energy supply per capita (Gigajoules)',
#        'Net Official Development Assist. received (% of GNI)',
#        'Education: Secondary gross enrol. ratio (female per 100 pop.)',
#        'Education: Secondary gross enrol. ratio (male per 100 pop.)',
#        'Education: Tertiary gross enrol. ratio (female per 100 pop.)',
#        'Education: Tertiary gross enrol. ratio (male per 100 pop.)',
#        'Life expectancy at birth (females, years)',
#        'Life expectancy at birth (males, years)',
#        'Pop. using improved drinking water (urban, %)',
#        'Pop. using improved drinking water (rural, %)',
#        'Pop. using improved sanitation facilities (urban, %)',
#        'Pop. using improved sanitation facilities (rural, %)',
#        'Population age distribution (0-14 years, %)',
#        'Population age distribution (60+ years, %)'],
#       dtype='object')

# %%
data_2017
# Out:
#                        country          Region Surface area (km2)  \
# 0                  Afghanistan    SouthernAsia             652864
# 1                      Albania  SouthernEurope              28748
# 2                      Algeria  NorthernAfrica            2381741
# 3               American Samoa       Polynesia                199
# 4                      Andorra  SouthernEurope                468
# ..                         ...             ...                ...
# 224  Wallis and Futuna Islands       Polynesia                142
# 225             Western Sahara  NorthernAfrica             266000
# 226                      Yemen     WesternAsia             527968
# 227                     Zambia   EasternAfrica             752612
# 228                   Zimbabwe   EasternAfrica             390757
#
#      Population in thousands (2017)  Population density (per km2, 2017)  \
# 0                             35530                                54.4
# 1                              2930                               106.9
# 2                             41318                                17.3
# 3                                56                               278.2
# 4                                77                               163.8
# ..                              ...                                 ...
# 224                              12                                84.1
# 225                             553                                 2.1
# 226                           28250                                53.5
# 227                           17094                                23.0
# 228                           16530                                42.7
#
#      Sex ratio (m per 100 f, 2017)  \
# 0                            106.3
# 1                            101.9
# 2                            102.0
# 3                            103.6
# 4                            102.3
# ..                             ...
# 224                           93.4
# 225                          110.1
# 226                          102.1
# 227                           98.5
# 228                           95.0
#
#      GDP: Gross domestic product (million current US$)  \
# 0                                              20270.0
# 1                                              11541.0
# 2                                             164779.0
# 3                                                  NaN
# 4                                               2812.0
# ..                                                 ...
# 224                                                NaN
# 225                                                NaN
# 226                                            29688.0
# 227                                            21255.0
# 228                                            13893.0
#
#     GDP growth rate (annual %, const. 2005 prices)  \
# 0                                             -2.4
# 1                                              2.6
# 2                                              3.8
# 3                                              NaN
# 4                                              0.8
# ..                                             ...
# 224                                            NaN
# 225                                            NaN
# 226                                          -28.1
# 227                                            2.9
# 228                                            1.1
#
#      GDP per capita (current US$) Economy: Agriculture (% of GVA)  ...  \
# 0                           623.2                            23.3  ...
# 1                          3984.2                            22.4  ...
# 2                          4154.1                            12.2  ...
# 3                             NaN                             NaN  ...
# 4                         39896.4                             0.5  ...
# ..                            ...                             ...  ...
# 224                           NaN                             NaN  ...
# 225                           NaN                             NaN  ...
# 226                        1106.4                            14.7  ...
# 227                        1311.1                             8.2  ...
# 228                         890.4                            13.0  ...
#
#      Education: Tertiary gross enrol. ratio (female per 100 pop.)  \
# 0                                                  3.7
# 1                                                 68.1
# 2                                                 45.1
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 224                                                NaN
# 225                                                NaN
# 226                                                6.1
# 227                                                3.4
# 228                                                8.0
#
#      Education: Tertiary gross enrol. ratio (male per 100 pop.)  \
# 0                                                 13.3
# 1                                                 48.7
# 2                                                 28.9
# 3                                                 None
# 4                                                 None
# ..                                                 ...
# 224                                               None
# 225                                               None
# 226                                               13.7
# 227                                                4.5
# 228                                                8.9
#
#     Life expectancy at birth (females, years)  \
# 0                                        63.5
# 1                                        79.9
# 2                                        76.5
# 3                                        77.8
# 4                                         NaN
# ..                                        ...
# 224                                      78.7
# 225                                      70.3
# 226                                      65.6
# 227                                      61.9
# 228                                      59.0
#
#     Life expectancy at birth (males, years)  \
# 0                                      61.0
# 1                                      75.6
# 2                                      74.1
# 3                                      71.1
# 4                                      None
# ..                                      ...
# 224                                    72.8
# 225                                    66.9
# 226                                    62.8
# 227                                    57.5
# 228                                    56.1
#
#     Pop. using improved drinking water (urban, %)  \
# 0                                            78.2
# 1                                            94.9
# 2                                            84.3
# 3                                           100.0
# 4                                           100.0
# ..                                            ...
# 224                                           NaN
# 225                                           NaN
# 226                                          72.0
# 227                                          85.6
# 228                                          97.0
#
#     Pop. using improved drinking water (rural, %)  \
# 0                                            47.0
# 1                                            95.2
# 2                                            81.8
# 3                                           100.0
# 4                                           100.0
# ..                                            ...
# 224                                          None
# 225                                          None
# 226                                          46.5
# 227                                          51.3
# 228                                          67.3
#
#     Pop. using improved sanitation facilities (urban, %)  \
# 0                                                 45.1
# 1                                                 95.5
# 2                                                 89.8
# 3                                                 62.5
# 4                                                100.0
# ..                                                 ...
# 224                                                NaN
# 225                                                NaN
# 226                                               92.5
# 227                                               55.6
# 228                                               49.3
#
#      Pop. using improved sanitation facilities (rural, %)  \
# 0                                                 27.0
# 1                                                 90.2
# 2                                                 82.2
# 3                                                 62.5
# 4                                                100.0
# ..                                                 ...
# 224                                               None
# 225                                               None
# 226                                               34.1
# 227                                               35.7
# 228                                               30.8
#
#      Population age distribution (0-14 years, %)  \
# 0                                           43.2
# 1                                           17.4
# 2                                           29.3
# 3                                           33.3
# 4                                           14.4
# ..                                           ...
# 224                                         25.5
# 225                                         28.1
# 226                                         39.9
# 227                                         44.8
# 228                                         41.2
#
#     Population age distribution (60+ years, %)
# 0                                          4.1
# 1                                         19.0
# 2                                          9.4
# 3                                          9.0
# 4                                         19.0
# ..                                         ...
# 224                                       15.4
# 225                                        5.4
# 226                                        4.6
# 227                                        3.7
# 228                                        4.2
#
# [229 rows x 55 columns]

# %%
happiness_2017
# Out:
#                       country  happiness.score
# 0                      Norway            7.537
# 1                     Denmark            7.522
# 2                     Iceland            7.504
# 3                 Switzerland            7.494
# 4                     Finland            7.469
# ..                        ...              ...
# 150                    Rwanda            3.471
# 151                     Syria            3.462
# 152                  Tanzania            3.349
# 153                   Burundi            2.905
# 154  Central African Republic            2.693
#
# [155 rows x 2 columns]

# %%
Fdata_2017 = pd.merge(data_2017, happiness_2017, on="country", how='inner')
Fdata_2017 = pd.DataFrame(Fdata_2017[['country', 'Population age distribution (60+ years, %)', 
                                      'Population age distribution (0-14 years, %)',
                                      'Pop. using improved sanitation facilities (rural, %)',
                                      'Pop. using improved sanitation facilities (urban, %)',
                                      'Pop. using improved drinking water (rural, %)',
                                      'Pop. using improved drinking water (urban, %)',
                                      'Life expectancy at birth (males, years)',
                                      'Life expectancy at birth (females, years)',
                                      'Education: Tertiary gross enrol. ratio (male per 100 pop.)',
                                      'Education: Tertiary gross enrol. ratio (female per 100 pop.)',
                                      'Education: Secondary gross enrol. ratio (male per 100 pop.)',
                                      'Education: Secondary gross enrol. ratio (female per 100 pop.)',
                                      'Infant mortality rate (per 1000 live births',
                                      'GDP per capita (current US$)',
                                      'Employment: Agriculture (% of employed)',
                                      'Employment: Services (% of employed)',
                                      'Individuals using the Internet (per 100 inhabitants)',
                                      'Fertility rate, total (live births per woman)',
                                      'Urban population (% of total population)',
                                      'Economy: Agriculture (% of GVA)', 
                                      'happiness.score']])

# %%
Fdata_2017
# Out:
#          country Population age distribution (60+ years, %)  \
# 0    Afghanistan                                        4.1
# 1        Albania                                       19.0
# 2        Algeria                                        9.4
# 3         Angola                                        4.0
# 4      Argentina                                       15.4
# ..           ...                                        ...
# 146    Venezuela                                        9.9
# 147      Vietnam                                       11.1
# 148        Yemen                                        4.6
# 149       Zambia                                        3.7
# 150     Zimbabwe                                        4.2
#
#     Population age distribution (0-14 years, %)  \
# 0                                          43.2
# 1                                          17.4
# 2                                          29.3
# 3                                          46.8
# 4                                          24.9
# ..                                          ...
# 146                                        27.6
# 147                                        23.1
# 148                                        39.9
# 149                                        44.8
# 150                                        41.2
#
#     Pop. using improved sanitation facilities (rural, %)  \
# 0                                                 27.0
# 1                                                 90.2
# 2                                                 82.2
# 3                                                 22.5
# 4                                                 98.3
# ..                                                 ...
# 146                                               69.9
# 147                                               69.7
# 148                                               34.1
# 149                                               35.7
# 150                                               30.8
#
#     Pop. using improved sanitation facilities (urban, %)  \
# 0                                                 45.1
# 1                                                 95.5
# 2                                                 89.8
# 3                                                 88.6
# 4                                                 96.2
# ..                                                 ...
# 146                                               97.5
# 147                                               94.4
# 148                                               92.5
# 149                                               55.6
# 150                                               49.3
#
#     Pop. using improved drinking water (rural, %)  \
# 0                                            47.0
# 1                                            95.2
# 2                                            81.8
# 3                                            28.2
# 4                                           100.0
# ..                                            ...
# 146                                          77.9
# 147                                          96.9
# 148                                          46.5
# 149                                          51.3
# 150                                          67.3
#
#     Pop. using improved drinking water (urban, %)  \
# 0                                            78.2
# 1                                            94.9
# 2                                            84.3
# 3                                            75.4
# 4                                            99.0
# ..                                            ...
# 146                                          95.0
# 147                                          99.1
# 148                                          72.0
# 149                                          85.6
# 150                                          97.0
#
#     Life expectancy at birth (males, years)  \
# 0                                      61.0
# 1                                      75.6
# 2                                      74.1
# 3                                      57.4
# 4                                      72.2
# ..                                      ...
# 146                                    69.9
# 147                                    70.7
# 148                                    62.8
# 149                                    57.5
# 150                                    56.1
#
#     Life expectancy at birth (females, years)  \
# 0                                        63.5
# 1                                        79.9
# 2                                        76.5
# 3                                        63.0
# 4                                        79.8
# ..                                        ...
# 146                                      78.2
# 147                                      80.3
# 148                                      65.6
# 149                                      61.9
# 150                                      59.0
#
#     Education: Tertiary gross enrol. ratio (male per 100 pop.)  ...  \
# 0                                                 13.3          ...
# 1                                                 48.7          ...
# 2                                                 28.9          ...
# 3                                                 10.4          ...
# 4                                                 63.5          ...
# ..                                                 ...          ...
# 146                                                NaN          ...
# 147                                               28.8          ...
# 148                                               13.7          ...
# 149                                                4.5          ...
# 150                                                8.9          ...
#
#     Education: Secondary gross enrol. ratio (female per 100 pop.)  \
# 0                                                 39.7
# 1                                                 92.5
# 2                                                101.7
# 3                                                 22.7
# 4                                                110.3
# ..                                                 ...
# 146                                               93.0
# 147                                                NaN
# 148                                               39.5
# 149                                                NaN
# 150                                               47.1
#
#     Infant mortality rate (per 1000 live births GDP per capita (current US$)  \
# 0                                          68.6                        623.2
# 1                                          14.6                       3984.2
# 2                                          27.7                       4154.1
# 3                                          65.4                       4714.1
# 4                                          13.7                      14564.5
# ..                                          ...                          ...
# 146                                        13.8                      11068.9
# 147                                        19.3                       2067.9
# 148                                        47.2                       1106.4
# 149                                        53.8                       1311.1
# 150                                        46.5                        890.4
#
#     Employment: Agriculture (% of employed)  \
# 0                                      61.6
# 1                                      41.4
# 2                                      10.8
# 3                                       4.2
# 4                                       2.0
# ..                                      ...
# 146                                    11.9
# 147                                    41.8
# 148                                    32.9
# 149                                    54.8
# 150                                    67.5
#
#      Employment: Services (% of employed)  \
# 0                                    28.5
# 1                                    40.3
# 2                                    54.7
# 3                                    58.2
# 4                                    73.1
# ..                                    ...
# 146                                  61.3
# 147                                  35.2
# 148                                  49.2
# 149                                  35.3
# 150                                  25.2
#
#     Individuals using the Internet (per 100 inhabitants)  \
# 0                                                  8.3
# 1                                                 63.3
# 2                                                 38.2
# 3                                                 12.4
# 4                                                 69.4
# ..                                                 ...
# 146                                               61.9
# 147                                               52.7
# 148                                               25.1
# 149                                               21.0
# 150                                               16.4
#
#     Fertility rate, total (live births per woman)  \
# 0                                             5.3
# 1                                             1.7
# 2                                             3.0
# 3                                             6.0
# 4                                             2.3
# ..                                            ...
# 146                                           2.4
# 147                                           2.0
# 148                                           4.4
# 149                                           5.2
# 150                                           4.0
#
#     Urban population (% of total population) Economy: Agriculture (% of GVA)  \
# 0                                       26.7                            23.3
# 1                                       57.4                            22.4
# 2                                       70.7                            12.2
# 3                                       44.1                             6.8
# 4                                       91.8                             6.0
# ..                                       ...                             ...
# 146                                     89.0                             5.3
# 147                                     33.6                            18.9
# 148                                     34.6                            14.7
# 149                                     40.9                             8.2
# 150                                     32.4                            13.0
#
#      happiness.score
# 0              3.794
# 1              4.644
# 2              5.872
# 3              3.795
# 4              6.599
# ..               ...
# 146            5.250
# 147            5.074
# 148            3.593
# 149            4.514
# 150            3.875
#
# [151 rows x 22 columns]

# %%
frames = [Fdata_2015, Fdata_2017]
final_dataset = pd.concat(frames)
final_dataset
# Out:
#          country Population age distribution (60+ years, %)  \
# 0    Afghanistan                                          4
# 1        Albania                                       17.9
# 2        Algeria                                        8.9
# 3         Angola                                        3.6
# 4      Argentina                                       14.9
# ..           ...                                        ...
# 146    Venezuela                                        9.9
# 147      Vietnam                                       11.1
# 148        Yemen                                        4.6
# 149       Zambia                                        3.7
# 150     Zimbabwe                                        4.2
#
#     Population age distribution (0-14 years, %)  \
# 0                                          44.9
# 1                                          18.7
# 2                                          28.7
# 3                                          47.1
# 4                                          25.2
# ..                                          ...
# 146                                        27.6
# 147                                        23.1
# 148                                        39.9
# 149                                        44.8
# 150                                        41.2
#
#     Pop. using improved sanitation facilities (rural, %)  \
# 0                                                  NaN
# 1                                                 50.1
# 2                                                 23.1
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 146                                               69.9
# 147                                               69.7
# 148                                               34.1
# 149                                               35.7
# 150                                               30.8
#
#     Pop. using improved sanitation facilities (urban, %)  \
# 0                                                  NaN
# 1                                                 43.5
# 2                                                 17.0
# 3                                                  NaN
# 4                                                 46.7
# ..                                                 ...
# 146                                               97.5
# 147                                               94.4
# 148                                               92.5
# 149                                               55.6
# 150                                               49.3
#
#     Pop. using improved drinking water (rural, %)  \
# 0                                            20.4
# 1                                             NaN
# 2                                            65.9
# 3                                             NaN
# 4                                             NaN
# ..                                            ...
# 146                                          77.9
# 147                                          96.9
# 148                                          46.5
# 149                                          51.3
# 150                                          67.3
#
#     Pop. using improved drinking water (urban, %)  \
# 0                                            32.4
# 1                                             NaN
# 2                                            79.5
# 3                                             NaN
# 4                                             NaN
# ..                                            ...
# 146                                          95.0
# 147                                          99.1
# 148                                          72.0
# 149                                          85.6
# 150                                          97.0
#
#     Life expectancy at birth (males, years)  \
# 0                                      60.9
# 1                                      75.2
# 2                                      74.4
# 3                                      55.2
# 4                                      72.2
# ..                                      ...
# 146                                    69.9
# 147                                    70.7
# 148                                    62.8
# 149                                    57.5
# 150                                    56.1
#
#     Life expectancy at birth (females, years)  \
# 0                                        63.8
# 1                                        80.0
# 2                                        76.7
# 3                                        60.5
# 4                                        79.0
# ..                                        ...
# 146                                      78.2
# 147                                      80.3
# 148                                      65.6
# 149                                      61.9
# 150                                      59.0
#
#     Education: Tertiary gross enrol. ratio (male per 100 pop.)  ...  \
# 0                                                 52.6          ...
# 1                                                 99.6          ...
# 2                                                  NaN          ...
# 3                                                  NaN          ...
# 4                                                 79.4          ...
# ..                                                 ...          ...
# 146                                                NaN          ...
# 147                                               28.8          ...
# 148                                               13.7          ...
# 149                                                4.5          ...
# 150                                                8.9          ...
#
#     Education: Secondary gross enrol. ratio (female per 100 pop.)  \
# 0                                                 36.8
# 1                                                 95.1
# 2                                                  NaN
# 3                                                  NaN
# 4                                                110.2
# ..                                                 ...
# 146                                               93.0
# 147                                                NaN
# 148                                               39.5
# 149                                                NaN
# 150                                               47.1
#
#     Infant mortality rate (per 1000 live births GDP per capita (current US$)  \
# 0                                          60.1                          544
# 1                                           9.2                         3939
# 2                                          24.9                         4178
# 3                                          78.2                         4167
# 4                                          12.1                        14971
# ..                                          ...                          ...
# 146                                        13.8                      11068.9
# 147                                        19.3                       2067.9
# 148                                        47.2                       1106.4
# 149                                        53.8                       1311.1
# 150                                        46.5                        890.4
#
#     Employment: Agriculture (% of employed)  \
# 0                                      47.1
# 1                                      41.4
# 2                                      10.3
# 3                                      50.6
# 4                                       0.3
# ..                                      ...
# 146                                    11.9
# 147                                    41.8
# 148                                    32.9
# 149                                    54.8
# 150                                    67.5
#
#     Employment: Services (% of employed)  \
# 0                                   35.8
# 1                                   40.0
# 2                                   58.7
# 3                                   40.8
# 4                                   76.1
# ..                                   ...
# 146                                 61.3
# 147                                 35.2
# 148                                 49.2
# 149                                 35.3
# 150                                 25.2
#
#     Individuals using the Internet (per 100 inhabitants)  \
# 0                                                  8.3
# 1                                                 63.3
# 2                                                 38.2
# 3                                                 12.4
# 4                                                   68
# ..                                                 ...
# 146                                               61.9
# 147                                               52.7
# 148                                               25.1
# 149                                               21.0
# 150                                               16.4
#
#     Fertility rate, total (live births per woman)  \
# 0                                             5.4
# 1                                             1.7
# 2                                             3.0
# 3                                             6.0
# 4                                             2.3
# ..                                            ...
# 146                                           2.4
# 147                                           2.0
# 148                                           4.4
# 149                                           5.2
# 150                                           4.0
#
#     Urban population (% of total population) Economy: Agriculture (% of GVA)  \
# 0                                       24.8                            27.3
# 1                                       57.4                            22.5
# 2                                       70.8                            12.1
# 3                                       63.4                             9.1
# 4                                       91.5                             6.1
# ..                                       ...                             ...
# 146                                     89.0                             5.3
# 147                                     33.6                            18.9
# 148                                     34.6                            14.7
# 149                                     40.9                             8.2
# 150                                     32.4                            13.0
#
#     happiness.score
# 0             3.575
# 1             4.959
# 2             5.605
# 3             4.033
# 4             6.574
# ..              ...
# 146           5.250
# 147           5.074
# 148           3.593
# 149           4.514
# 150           3.875
#
# [302 rows x 22 columns]

# %%
cols = list(final_dataset.columns)

# %%
sb.heatmap(final_dataset.isnull(),cbar=False,cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
final_dataset.isnull().mean() * 100
# Out:
# country                                                           0.000000
# Population age distribution (60+ years, %)                        0.331126
# Population age distribution (0-14 years, %)                       0.331126
# Pop. using improved sanitation facilities (rural, %)             30.132450
# Pop. using improved sanitation facilities (urban, %)             23.509934
# Pop. using improved drinking water (rural, %)                    33.443709
# Pop. using improved drinking water (urban, %)                    28.476821
# Life expectancy at birth (males, years)                           0.331126
# Life expectancy at birth (females, years)                         0.331126
# Education: Tertiary gross enrol. ratio (male per 100 pop.)       21.192053
# Education: Tertiary gross enrol. ratio (female per 100 pop.)     21.192053
# Education: Secondary gross enrol. ratio (male per 100 pop.)      20.198675
# Education: Secondary gross enrol. ratio (female per 100 pop.)    20.198675
# Infant mortality rate (per 1000 live births                       0.331126
# GDP per capita (current US$)                                      0.000000
# Employment: Agriculture (% of employed)                           0.662252
# Employment: Services (% of employed)                              0.662252
# Individuals using the Internet (per 100 inhabitants)              0.331126
# Fertility rate, total (live births per woman)                     0.331126
# Urban population (% of total population)                          0.331126
# Economy: Agriculture (% of GVA)                                   0.331126
# happiness.score                                                   0.000000
# dtype: float64

# %%
final_dataset = final_dataset.loc[:, final_dataset.columns != 'country'].astype('float64')
final_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 302 entries, 0 to 150
# Data columns (total 21 columns):
#  #   Column                                                         Non-Null Count  Dtype
# ---  ------                                                         --------------  -----
#  0   Population age distribution (60+ years, %)                     301 non-null    float64
#  1   Population age distribution (0-14 years, %)                    301 non-null    float64
#  2   Pop. using improved sanitation facilities (rural, %)           211 non-null    float64
#  3   Pop. using improved sanitation facilities (urban, %)           231 non-null    float64
#  4   Pop. using improved drinking water (rural, %)                  201 non-null    float64
#  5   Pop. using improved drinking water (urban, %)                  216 non-null    float64
#  6   Life expectancy at birth (males, years)                        301 non-null    float64
#  7   Life expectancy at birth (females, years)                      301 non-null    float64
#  8   Education: Tertiary gross enrol. ratio (male per 100 pop.)     238 non-null    float64
#  9   Education: Tertiary gross enrol. ratio (female per 100 pop.)   238 non-null    float64
#  10  Education: Secondary gross enrol. ratio (male per 100 pop.)    241 non-null    float64
#  11  Education: Secondary gross enrol. ratio (female per 100 pop.)  241 non-null    float64
#  12  Infant mortality rate (per 1000 live births                    301 non-null    float64
#  13  GDP per capita (current US$)                                   302 non-null    float64
#  14  Employment: Agriculture (% of employed)                        300 non-null    float64
#  15  Employment: Services (% of employed)                           300 non-null    float64
#  16  Individuals using the Internet (per 100 inhabitants)           301 non-null    float64
#  17  Fertility rate, total (live births per woman)                  301 non-null    float64
#  18  Urban population (% of total population)                       301 non-null    float64
#  19  Economy: Agriculture (% of GVA)                                301 non-null    float64
#  20  happiness.score                                                302 non-null    float64
# dtypes: float64(21)
# memory usage: 51.9 KB

# %%
final_dataset.isnull().sum()
# Out:
# Population age distribution (60+ years, %)                       0
# Population age distribution (0-14 years, %)                      0
# Pop. using improved sanitation facilities (rural, %)             0
# Pop. using improved sanitation facilities (urban, %)             0
# Pop. using improved drinking water (rural, %)                    0
# Pop. using improved drinking water (urban, %)                    0
# Life expectancy at birth (males, years)                          0
# Life expectancy at birth (females, years)                        0
# Education: Tertiary gross enrol. ratio (male per 100 pop.)       0
# Education: Tertiary gross enrol. ratio (female per 100 pop.)     0
# Education: Secondary gross enrol. ratio (male per 100 pop.)      0
# Education: Secondary gross enrol. ratio (female per 100 pop.)    0
# Infant mortality rate (per 1000 live births                      0
# GDP per capita (current US$)                                     0
# Employment: Agriculture (% of employed)                          0
# Employment: Services (% of employed)                             0
# Individuals using the Internet (per 100 inhabitants)             0
# Fertility rate, total (live births per woman)                    0
# Urban population (% of total population)                         0
# Economy: Agriculture (% of GVA)                                  0
# happiness.score                                                  0
# dtype: int64

# %%
from sklearn.impute import KNNImputer

# %%
impute_knn = KNNImputer(n_neighbors = 5)
final_dataset = pd.DataFrame(impute_knn.fit_transform(final_dataset), columns=final_dataset.columns)

# %%
final_dataset
# Out:
#      Population age distribution (60+ years, %)  \
# 0                                           4.0
# 1                                          17.9
# 2                                           8.9
# 3                                           3.6
# 4                                          14.9
# ..                                          ...
# 297                                         9.9
# 298                                        11.1
# 299                                         4.6
# 300                                         3.7
# 301                                         4.2
#
#      Population age distribution (0-14 years, %)  \
# 0                                           44.9
# 1                                           18.7
# 2                                           28.7
# 3                                           47.1
# 4                                           25.2
# ..                                           ...
# 297                                         27.6
# 298                                         23.1
# 299                                         39.9
# 300                                         44.8
# 301                                         41.2
#
#      Pop. using improved sanitation facilities (rural, %)  \
# 0                                                10.18
# 1                                                50.10
# 2                                                23.10
# 3                                                67.14
# 4                                                90.72
# ..                                                 ...
# 297                                              69.90
# 298                                              69.70
# 299                                              34.10
# 300                                              35.70
# 301                                              30.80
#
#      Pop. using improved sanitation facilities (urban, %)  \
# 0                                                23.04
# 1                                                43.50
# 2                                                17.00
# 3                                                73.74
# 4                                                46.70
# ..                                                 ...
# 297                                              97.50
# 298                                              94.40
# 299                                              92.50
# 300                                              55.60
# 301                                              49.30
#
#      Pop. using improved drinking water (rural, %)  \
# 0                                            20.40
# 1                                            63.02
# 2                                            65.90
# 3                                            85.82
# 4                                            96.52
# ..                                             ...
# 297                                          77.90
# 298                                          96.90
# 299                                          46.50
# 300                                          51.30
# 301                                          67.30
#
#      Pop. using improved drinking water (urban, %)  \
# 0                                            32.40
# 1                                            74.86
# 2                                            79.50
# 3                                            92.20
# 4                                            98.40
# ..                                             ...
# 297                                          95.00
# 298                                          99.10
# 299                                          72.00
# 300                                          85.60
# 301                                          97.00
#
#      Life expectancy at birth (males, years)  \
# 0                                       60.9
# 1                                       75.2
# 2                                       74.4
# 3                                       55.2
# 4                                       72.2
# ..                                       ...
# 297                                     69.9
# 298                                     70.7
# 299                                     62.8
# 300                                     57.5
# 301                                     56.1
#
#      Life expectancy at birth (females, years)  \
# 0                                         63.8
# 1                                         80.0
# 2                                         76.7
# 3                                         60.5
# 4                                         79.0
# ..                                         ...
# 297                                       78.2
# 298                                       80.3
# 299                                       65.6
# 300                                       61.9
# 301                                       59.0
#
#      Education: Tertiary gross enrol. ratio (male per 100 pop.)  \
# 0                                                52.60
# 1                                                99.60
# 2                                                35.72
# 3                                                35.72
# 4                                                79.40
# ..                                                 ...
# 297                                              77.96
# 298                                              28.80
# 299                                              13.70
# 300                                               4.50
# 301                                               8.90
#
#      Education: Tertiary gross enrol. ratio (female per 100 pop.)  ...  \
# 0                                                27.10             ...
# 1                                                89.60             ...
# 2                                                49.48             ...
# 3                                                49.48             ...
# 4                                                91.10             ...
# ..                                                 ...             ...
# 297                                              89.50             ...
# 298                                              28.90             ...
# 299                                               6.10             ...
# 300                                               3.40             ...
# 301                                               8.00             ...
#
#      Education: Secondary gross enrol. ratio (female per 100 pop.)  \
# 0                                                36.80
# 1                                                95.10
# 2                                                89.08
# 3                                                89.08
# 4                                               110.20
# ..                                                 ...
# 297                                              93.00
# 298                                              56.16
# 299                                              39.50
# 300                                              46.68
# 301                                              47.10
#
#      Infant mortality rate (per 1000 live births  \
# 0                                           60.1
# 1                                            9.2
# 2                                           24.9
# 3                                           78.2
# 4                                           12.1
# ..                                           ...
# 297                                         13.8
# 298                                         19.3
# 299                                         47.2
# 300                                         53.8
# 301                                         46.5
#
#      GDP per capita (current US$)  Employment: Agriculture (% of employed)  \
# 0                           544.0                                     47.1
# 1                          3939.0                                     41.4
# 2                          4178.0                                     10.3
# 3                          4167.0                                     50.6
# 4                         14971.0                                      0.3
# ..                            ...                                      ...
# 297                       11068.9                                     11.9
# 298                        2067.9                                     41.8
# 299                        1106.4                                     32.9
# 300                        1311.1                                     54.8
# 301                         890.4                                     67.5
#
#      Employment: Services (% of employed)  \
# 0                                    35.8
# 1                                    40.0
# 2                                    58.7
# 3                                    40.8
# 4                                    76.1
# ..                                    ...
# 297                                  61.3
# 298                                  35.2
# 299                                  49.2
# 300                                  35.3
# 301                                  25.2
#
#      Individuals using the Internet (per 100 inhabitants)  \
# 0                                                  8.3
# 1                                                 63.3
# 2                                                 38.2
# 3                                                 12.4
# 4                                                 68.0
# ..                                                 ...
# 297                                               61.9
# 298                                               52.7
# 299                                               25.1
# 300                                               21.0
# 301                                               16.4
#
#      Fertility rate, total (live births per woman)  \
# 0                                              5.4
# 1                                              1.7
# 2                                              3.0
# 3                                              6.0
# 4                                              2.3
# ..                                             ...
# 297                                            2.4
# 298                                            2.0
# 299                                            4.4
# 300                                            5.2
# 301                                            4.0
#
#      Urban population (% of total population)  \
# 0                                        24.8
# 1                                        57.4
# 2                                        70.8
# 3                                        63.4
# 4                                        91.5
# ..                                        ...
# 297                                      89.0
# 298                                      33.6
# 299                                      34.6
# 300                                      40.9
# 301                                      32.4
#
#      Economy: Agriculture (% of GVA)  happiness.score
# 0                               27.3            3.575
# 1                               22.5            4.959
# 2                               12.1            5.605
# 3                                9.1            4.033
# 4                                6.1            6.574
# ..                               ...              ...
# 297                              5.3            5.250
# 298                             18.9            5.074
# 299                             14.7            3.593
# 300                              8.2            4.514
# 301                             13.0            3.875
#
# [302 rows x 21 columns]

# %%
f = plt.figure(figsize=(20, 20))
sb.heatmap(final_dataset.corr(), vmin = -1, vmax = 1, linewidths = 1,
           annot = True, fmt = ".2f", annot_kws = {"size": 18}, cmap = "RdBu")
# Out:
# <AxesSubplot:>
